# %% [markdown]
# # 1 Module, Globals und Daten
# ## 1.1 Module

# %%
##### IMPORTS #####
import matplotlib.pyplot as pyplot
import pandas as pd
from sklearn.model_selection import train_test_split
import sklearn.metrics as skm
from xgboost import XGBClassifier

import xgboost as xgb

# %% [markdown]
# ## 1.2 Globals

# %%
##### Globals #####
datasetsPath = 'datasets/harus/'                # Set location of dataset

# %% [markdown]
# ## 1.3 Daten

# %%
xdata = pd.read_csv(datasetsPath + "xdata.csv", sep=";")                     
ydata = pd.read_csv(datasetsPath + "ydata.csv", sep=";")

xtrain, xtest, ytrain, ytest = train_test_split( 
    xdata,
    ydata,
    random_state=0,
    train_size=0.33,
    stratify=ydata
)

ev_test = [(xtest,ytest)]
ev_both = [(xtrain,ytrain),(xtest,ytest)]

# %% [markdown]
# ## 1.4 Training und Prediction

# %%
model = XGBClassifier()
model.set_params(objective = "multi:softmax",
                 num_class = 6,
                 tree_method = 'exact')
model.fit(xtrain, 
          ytrain,
          eval_set = ev_both,
          verbose = 0)

yhat = model.predict(xtest)

# %% [markdown]
# ## 1.5 Eval

# %%
print(f'Accuracy Score: \t\t{skm.accuracy_score(ytest, yhat)}')          # 0.9828310161425772 stratified | 0.981664644956611  naive  | 0.9534384622562284 scale_pos_weight = len(0s)/len(1s)
print(f'Balanced Accuracy-Score: \t{skm.balanced_accuracy_score(ytest, yhat)}') # 0.5990495790838934 stratified | 0.5770402535045962 naive  | 0.8314600386751905 scale_pos_weight = len(0s)/len(1s)
print()
print(skm.classification_report(ytest,yhat, labels=[0,1], target_names=['0: standing','1: walking']))

skm.ConfusionMatrixDisplay.from_estimator(model, xtest, ytest, cmap='Blues', normalize='true')
pyplot.title('')
pyplot.show()

skm.ConfusionMatrixDisplay.from_estimator(model, xtest, ytest, cmap="Blues" ,values_format='d')
# skm.ConfusionMatrixDisplay.from_estimator(model, xtest, ytest, cmap='Blues', values_format='d')
pyplot.show()
# Out:
# Accuracy Score: 		0.9794232719895667
# Balanced Accuracy-Score: 	0.9798840668229561
#
#               precision    recall  f1-score   support
#
#  0: standing       1.00      0.99      1.00      1154
#   1: walking       0.98      0.99      0.99      1034
#
#    micro avg       0.99      0.99      0.99      2188
#    macro avg       0.99      0.99      0.99      2188
# weighted avg       0.99      0.99      0.99      2188

# %%
iScores = model.feature_importances_
fNames = model.feature_names_in_

impNames = [(iScores[i],fNames[i]) for i in range(0,len(iScores))]
sorted_impNames = sorted(impNames, key=lambda tup: tup[0], reverse=True)

iScores_sorted_top = []
fNames_sorted_top = []

for i in sorted_impNames[:20]:
    iScores_sorted_top.append(i[0])
    fNames_sorted_top.append(i[1])

fig,ax = pyplot.subplots()

# Regular Bar Plot
ax.barh(fNames_sorted_top, iScores_sorted_top)
ax.invert_yaxis()
ax.set_ylabel("Merkmale/Features")
ax.set_xlabel("Importance Score")

fig.set_figwidth(10)
fig.set_figheight(7)

pyplot.tight_layout()

# %%
fig,ax = pyplot.subplots()

iScores_sorted = []
fNames_sorted = []

for i in sorted_impNames:
    iScores_sorted.append(i[0])
    fNames_sorted.append(i[1])

# Regular Bar Plot
ax.barh(fNames_sorted, iScores_sorted)
ax.invert_yaxis()
ax.set_ylabel("Merkmale/Features")
ax.set_xlabel("Importance Score")

fig.set_figwidth(10)
fig.set_figheight(125)

pyplot.tight_layout()
