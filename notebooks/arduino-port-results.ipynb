# %% [markdown]
# # 0 Imports

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

# %% [markdown]
# ## 1.0 Sketch / Wie die Zeiten genommen wurden

# %% [raw]
# #define INPUT_SIZE // [Anzahl Merkmale]
# #define OUTPUT_SIZE // [Anzahl Klassen]
# #define BAUD 9600
#
# double input[INPUT_SIZE];
# double output[OUTPUT_SIZE];
# unsigned long duration;
# unsigned long start;
# unsigned long end;
#
# // Die Modellbezogenen Funktionen wurden hier weggelassen, da diese modellspezifisch sind
# // Die Zeitnahme erfolgt jedoch immer auf die gleiche Art und Weise
# // Der Funktionsaufruf ist in diesem Code-Snippet jedoch enthalten
#
# void setup() {
#   Serial.begin(BAUD);
#   randomSeed(0);        // Fuer Reproduzierbarkeit
# }
#
# void loop() {
#   duration = 0;
#   for(int i=0; i<1000; i++) {
#     fillArray(input);
#     start = micros();
#     // start = millis();
#     score(input, output);
#     end = micros();
#     // end = millis();
#     duration += (end - start);
#   }
#   Serial.print(duration);
#   Serial.print(", ");
# }
#
# void fillArray(double * array) {
#   long randomVal;
#   double randomDec;
#
#   for(int i = 0; i<INPUT_SIZE; i++){
#     randomVal = random(-200000,200001);
#     randomDec = (double)randomVal / 10000;
#     array[i] = randomDec;
#   }
# }

# %% [markdown]
# ## 1.1 Gyro

# %% [markdown]
# ### 1.1.1 Millisekunden (langsamer)

# %%
base_gyro_millis = [
    4206, 4184, 4189, 4204, 4204, 4188, 4181, 4190, 4200, 4196,
    4178, 4198, 4198, 4194, 4189, 4185, 4210, 4198, 4195, 4182, 
    4203, 4207, 4193, 4188, 4193, 4199, 4189, 4182, 4192, 4209, 
    4196, 4192, 4199, 4194, 4196, 4196, 4196, 4213, 4206, 4202, 
    4182, 4207, 4194, 4176, 4177, 4207, 4207, 4207, 4186, 4186, 
    ]

print(len(base_gyro_millis))

print(f'Minimale Inferenzdauer: \t\t\t{min(base_gyro_millis)} ms')
print(f'Maximale Inferenzdauer: \t\t\t{max(base_gyro_millis)} ms')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(base_gyro_millis)/len(base_gyro_millis)} ms')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(base_gyro_millis)/len(base_gyro_millis))/1000} ms')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(base_gyro_millis)/len(base_gyro_millis))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000/((sum(base_gyro_millis)/len(base_gyro_millis))/1000))}')

print("\n!!! MILLISEKUNDEN ZU ERMITTELN DAUERT LÄNGER AUF DEM ARDUINO !!!")
# Out:
# 50
# Minimale Inferenzdauer: 			4176 ms
# Maximale Inferenzdauer: 			4213 ms
# Durchschnittliche Inferenzdauer: 		4194.86 ms
# Durchschnittliche Inferenzdauer pro Instanz: 	4.194859999999999 ms
# Inferenzen pro Sekunde: 			238386.97834969466
# Inferenzen pro Sekunde (gerundet): 		238
#
# !!! MILLISEKUNDEN ZU ERMITTELN DAUERT LÄNGER AUF DEM ARDUINO !!!

# %% [markdown]
# ### 1.1.1 µ-Sekunden

# %%
base_gyro_micros = [
    4060798, 4062132, 4060959, 4064614, 4063872, 4066401, 4064696, 4064284, 4065308, 4062355, 
    4065072, 4061462, 4061728, 4064475, 4060684, 4057053, 4062696, 4062622, 4061955, 4062623, 
    4063950, 4059761, 4058905, 4065272, 4063534, 4058903, 4065599, 4062075, 4061944, 4063155, 
    4061684, 4065621, 4062188, 4062671, 4061120, 4067814, 4062747, 4061193, 4065218, 4064752, 
    4065815, 4062166, 4065957, 4059836, 4058773, 4061303, 4062596, 4064203, 4062804, 4061171
    ]

print(len(base_gyro_micros))

print(f'Minimale Inferenzdauer: \t\t\t{min(base_gyro_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(base_gyro_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(base_gyro_micros)/len(base_gyro_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(base_gyro_micros)/len(base_gyro_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(base_gyro_micros)/len(base_gyro_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(base_gyro_micros)/len(base_gyro_micros))/1000))}')
# Out:
# 50
# Minimale Inferenzdauer: 			4057053 µs
# Maximale Inferenzdauer: 			4067814 µs
# Durchschnittliche Inferenzdauer: 		4062770.38 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	4062.77038 µs
# Inferenzen pro Sekunde: 			246.13746445596564
# Inferenzen pro Sekunde (gerundet): 		246

# %% [markdown]
# ## 1.2 Harus

# %%
base_harus_micros = [
    4800518, 4800307, 4800508, 4799054, 4802106, 4800131, 4799620, 4799332, 4802152, 4802960, 
    4799278, 4801756, 4802600, 4801237, 4803206, 4799958, 4801087, 4800965, 4804529, 4800686, 
    4801551, 4800663, 4801272, 4802217, 4801075, 4801995, 4802157, 4800523, 4799169, 4801614, 
    4802980, 4803860, 4801878, 4798048, 4801675, 4799351, 4801220, 4800915, 4800814, 4804521, 
    4801008, 4798067, 4803456, 4800772, 4802118, 4802115, 4804179, 4798253, 4802477, 4800696
    ]

print(len(base_harus_micros))

print(f'Minimale Inferenzdauer: \t\t\t{min(base_harus_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(base_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(base_harus_micros)/len(base_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(base_harus_micros)/len(base_harus_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(base_harus_micros)/len(base_harus_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(base_harus_micros)/len(base_harus_micros))/1000))}')
# Out:
# 50
# Minimale Inferenzdauer: 			4798048 µs
# Maximale Inferenzdauer: 			4804529 µs
# Durchschnittliche Inferenzdauer: 		4801252.58 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	4801.25258 µs
# Inferenzen pro Sekunde: 			208.27898206513433
# Inferenzen pro Sekunde (gerundet): 		208

# %% [markdown]
# ## 1.3 Mushroom

# %%
base_mushroom_micros = [
    2959611, 2948299, 2953792, 2956912, 2964099, 2967792, 2952340, 2948886, 2961857, 2950536, 
    2970717, 2953493, 2959986, 2958252, 2956719, 2951790, 2955868, 2963159, 2956951, 2962360, 
    2950317, 2954283, 2953594, 2954307, 2962173, 2958301, 2969568, 2960417, 2951993, 2956142, 
    2960001, 2959470, 2963524, 2962423, 2958874, 2958074, 2956744, 2949139, 2952669, 2952765, 
    2962543, 2948422, 2955580, 2959646, 2957185, 2969083, 2956859, 2956449, 2958839, 2954095
    ]

print(f'Minimale Inferenzdauer: \t\t\t{min(base_mushroom_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(base_mushroom_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(base_mushroom_micros)/len(base_mushroom_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(base_mushroom_micros)/len(base_mushroom_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(base_mushroom_micros)/len(base_mushroom_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(base_mushroom_micros)/len(base_mushroom_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			2948299 µs
# Maximale Inferenzdauer: 			2970717 µs
# Durchschnittliche Inferenzdauer: 		2957537.96 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	2957.53796 µs
# Inferenzen pro Sekunde: 			338.11907523242746
# Inferenzen pro Sekunde (gerundet): 		338

# %% [markdown]
# # 2 Programm Space in Bytes Basemodelle
#
# - Dynamic Memory unterscheidet sich hier nur auf Basis der Arraygrößen (und deren Datentypen)
# - Percentage ist abgeschnitten und nicht gerundet!
#
# **Boilerplate -> Leeres setup() und loop()**
#
# |Storage                    |Used  |Maximum |Percentage|
# |:--------------------------|:----:|-------:|---------:|
# |Program Storage            |85264 |983040  |        8%|
# |Dynamic Memory/Global vars |44552 |262144  |       16%|
# |Left for local vars        | -    |217592  |       -  |
#
# ## 2.1 Gyro
#
# **Modell + fillArray + input[6] + output[2]**
#
# |Storage                    |Used  |Maximum |Percentage|
# |:--------------------------|:----:|-------:|---------:|
# |Program Storage            |190152|983040  |       19%|
# |Dynamic Memory/Global vars |44616 |262144  |       17%|
# |Left for local vars        | -    |217528  |       -  |
#
# ## 2.2 Harus
#
# |Storage                    |Used  |Maximum|Percentage|
# |:--------------------------|:----:|------:|---------:|
# |Program Storage            |310664|983040 |       31%|
# |Dynamic Memory/Global vars |49088 |262144 |       18%|
# |Left for local vars        | -    |213056 |       -  |
#
# ## 2.3 Mushroom
#
# |Storage                    |Used  |Maximum|Percentage|
# |:--------------------------|:----:|------:|---------:|
# |Program Storage            |302984|983040 |       30%|
# |Dynamic Memory/Global vars |45592 |262144 |       17%|
# |Left for local vars        | -    |216552 |       -  |

# %% [markdown]
# # 4 Performance

# %% [markdown]
# ## 4.1 Gyro

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

port_scores = pd.read_csv("datasets/port-scores/base_gyro_scores.csv")
ypred = port_scores["class"]
ytrue = pd.read_csv("datasets/gyro/ytest.csv")['Activity']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.balanced_accuracy_score(ytrue,ypred))

Spec = 0.885436
Recall = 0,865979
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   0.120690  0.865979  0.211854        97
#   1: walking   0.997259  0.885436  0.938027      5342
#
#     accuracy                       0.885089      5439
#    macro avg   0.558974  0.875708  0.574940      5439
# weighted avg   0.981626  0.885089  0.925076      5439
#
# 0.8757077738365877

# %% [markdown]
# |Leistungskennzahlen AGMP-Port ||
# |:--------------------------|-----:|
# |Sensitivität           |0,885436|
# |Spezifität             |0,865979|
# |Präzision              |0,997259|
# |F1 Wert                |0,938026|
# |Balancierte Genauigkeit|0.875708|
#
# (Identisch mit Original)

# %% [markdown]
# ## 4.2 Harus

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

def calculate_confusion_counts(ycompare, values):
    sumtp, sumfp, sumtn, sumfn = 0, 0, 0, 0
    for val in values:
        tp = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] == val)].shape[0]
        fn = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] != val)].shape[0]
        tn = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] != val)].shape[0]
        fp = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] == val)].shape[0]

        sumtp += tp
        sumfp += fp
        sumtn += tn
        sumfn += fn

        print(f'{val}: TP {tp}, FP {fp}, TN {tn}, FN {fn}')
        
    print(f'Total: TP {sumtp}, FP {sumfp}, TN {sumtn}, FN {sumfn}')

port_scores = pd.read_csv("datasets/port-scores/base_harus_scores.csv")
ypred = port_scores["class"]
ytrue = pd.read_csv("datasets/harus/ytest.csv")['label']

ycompare = pd.concat([ytrue,ypred],axis=1)
ycompare = ycompare.rename(columns={"label": "true", "class": "predicted"})

calculate_confusion_counts(ycompare, [0,1,2,3,4,5])

tp0, tp1, tp2, tp3, tp4, tp5 = 290, 263, 235, 293, 317, 330
sumtp = tp0+tp1+tp2+tp3+tp4+tp5

fp0, fp1, fp2, fp3, fp4, fp5 = 3, 0, 4, 9, 7, 0
sumfp = fp0 + fp1 + fp2 + fp3 + fp4 + fp5

tn0, tn1, tn2, tn3, tn4, tn5 = 1455, 1486, 1509, 1442, 1419, 1421
sumtn = tn0 + tn1 + tn2 + tn3 + tn4 + tn5

fn0, fn1, fn2, fn3, fn4, fn5 = 3, 2, 3, 7, 8, 0
sumfn = fn0 + fn1 + fn2 + fn3 + fn4 + fn5

sens = sumtp/(sumtp + sumfp)
spec = sumtn/(sumtn + sumfn)
prec = sumtp/(sumtp + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
# Out:
# 0: TP 290, FP 3, TN 1455, FN 3
# 1: TP 263, FP 2, TN 1486, FN 0
# 2: TP 235, FP 3, TN 1509, FN 4
# 3: TP 293, FP 7, TN 1442, FN 9
# 4: TP 317, FP 8, TN 1419, FN 7
# 5: TP 330, FP 0, TN 1421, FN 0
# Total: TP 1728, FP 23, TN 8732, FN 23
#
# Genauigkeit: 0.986865
# Präzision (eigene Berechnung): 0.986865
# Sensitivität: 0.986865
# Spezifität: 0.997373
# NPV: 0.997373
# F1-Score: 0.986865
# F1-Score (eigene Berechnung): 0.986865
#
#               precision    recall  f1-score   support
#
#            0   0.989761  0.989761  0.989761       293
#            1   0.992453  1.000000  0.996212       263
#            2   0.987395  0.983264  0.985325       239
#            3   0.976667  0.970199  0.973422       302
#            4   0.975385  0.978395  0.976888       324
#            5   1.000000  1.000000  1.000000       330
#
#     accuracy                       0.986865      1751
#    macro avg   0.986943  0.986936  0.986935      1751
# weighted avg   0.986853  0.986865  0.986854      1751

# %% [markdown]
# |Leistungskennzahlen HARUS-Port |        |
# |:------------------------------|-------:|
# |Sensitivität                   |0.986865|
# |Spezifität                     |0.997373|
# |Präzision                      |0.986853|
# |F1 Wert                        |0.986854|
# |Genauigkeit                    |0.986865|
#
# Leichte Abweichungen (möglicherweise Aufgrund vom Verlust signifikanter Dezimalstellen)
#
# Abweicher nochmal auf Arduino überprüfen!

# %% [markdown]
# ## 4.3 Mushroom

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

port_scores = pd.read_csv("datasets/port-scores/base_mushroom_scores_neu.csv")
ypred = port_scores["class"]
ytrue = pd.read_csv("datasets/mushroom/ytest.csv")['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
skm.accuracy_score(ytrue,ypred)
# Out:
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000      4621
#            1   1.000000  1.000000  1.000000      5761
#
#     accuracy                       1.000000     10382
#    macro avg   1.000000  1.000000  1.000000     10382
# weighted avg   1.000000  1.000000  1.000000     10382
# 1.0

# %% [markdown]
# # 5 Zeiten Feature Selection

# %% [markdown]
# Ja... ehm...

# %% [markdown]
# ## 5.1 FS AGMP

# %%
# Sketch uses 126920 bytes (12%) of program storage space. Maximum is 983040 bytes.
# Global variables use 44624 bytes (17%) of dynamic memory, leaving 217520 bytes for local variables. Maximum is 262144 bytes.

# Sketch emb_agmp_empty : 74,3 KB (76.114 Bytes)

emb_agmp_micros = [
    1725674, 1726742, 1724877, 1725925, 1725740, 1725206, 1726983, 1725526, 1725706, 1725414, 
    1724840, 1726196, 1724189, 1725103, 1725552, 1723557, 1723818, 1725079, 1724619, 1725242, 
    1724957, 1725496, 1724761, 1724475, 1724660, 1724900, 1725869, 1724023, 1725711, 1726040, 
    1725391, 1725595, 1726602, 1725493, 1725761, 1725051, 1725170, 1725455, 1725410, 1726433, 
    1726337, 1725398, 1724215, 1726093, 1725050, 1726163, 1725509, 1726916, 1724203, 1723884
]

print(f'Minimale Inferenzdauer: \t\t\t{min(emb_agmp_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(emb_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(emb_agmp_micros)/len(emb_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(emb_agmp_micros)/len(emb_agmp_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(emb_agmp_micros)/len(emb_agmp_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(emb_agmp_micros)/len(emb_agmp_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			1723557 µs
# Maximale Inferenzdauer: 			1726983 µs
# Durchschnittliche Inferenzdauer: 		1725340.18 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	1725.34018 µs
# Inferenzen pro Sekunde: 			579.5958452668738
# Inferenzen pro Sekunde (gerundet): 		579

# %% [markdown]
# ## 5.2 RFECV AGMP

# %%
# Sketch uses 112008 bytes (11%) of program storage space. Maximum is 983040 bytes.
# Global variables use 44600 bytes (17%) of dynamic memory, leaving 217544 bytes for local variables. Maximum is 262144 bytes.

# Sketch rfecv_agmp_empty : 45,8 KB (46.930 Bytes) 45,830078125

rfecv_agmp_micros = [
    1084830, 1085145, 1087247, 1085876, 1086772, 1085940, 1085763, 1086348, 1086551, 1088376, 
    1088951, 1085957, 1086420, 1085790, 1088328, 1087128, 1086739, 1086256, 1087479, 1084516, 
    1088377, 1084561, 1086997, 1085905, 1087000, 1086362, 1085669, 1086195, 1085793, 1084874, 
    1085845, 1087640, 1087098, 1086142, 1085898, 1085503, 1086357, 1085274, 1086118, 1084785, 
    1086505, 1084704, 1086383, 1085714, 1085941, 1086064, 1085074, 1085359, 1085476, 1085590, 
    ]

print(f'Minimale Inferenzdauer: \t\t\t{min(rfecv_agmp_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(rfecv_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(rfecv_agmp_micros)/len(rfecv_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(rfecv_agmp_micros)/len(rfecv_agmp_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(rfecv_agmp_micros)/len(rfecv_agmp_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(rfecv_agmp_micros)/len(rfecv_agmp_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			1084516 µs
# Maximale Inferenzdauer: 			1088951 µs
# Durchschnittliche Inferenzdauer: 		1086192.3 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	1086.1923000000002 µs
# Inferenzen pro Sekunde: 			920.6472923809162
# Inferenzen pro Sekunde (gerundet): 		920

# %% [markdown]
# ## 5.3 FS HARUS

# %%
# Sketch uses 286216 bytes (29%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45648 bytes (17%) of dynamic memory, leaving 216496 bytes for local variables. Maximum is 262144 bytes.

# Sketch emb_harus_empty: 460 KB (471.092 Bytes)

emb_harus_micros = [
    5021675, 5023456, 5025135, 5024126, 5022500, 5024807, 5023715, 5025229, 5023357, 5026354, 
    5022563, 5025249, 5023326, 5023259, 5024626, 5024264, 5023566, 5022543, 5021990, 5024382, 
    5021749, 5024048, 5023217, 5024102, 5022503, 5024757, 5025127, 5022395, 5021513, 5022486, 
    5022984, 5022701, 5021649, 5024257, 5022716, 5022731, 5024498, 5024161, 5024992, 5020059, 
    5023092, 5022955, 5023925, 5025650, 5022813, 5025693, 5021989, 5023482, 5023009, 5022874 
]

print(f'Minimale Inferenzdauer: \t\t\t{min(emb_harus_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(emb_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(emb_harus_micros)/len(emb_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(emb_harus_micros)/len(emb_harus_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(emb_harus_micros)/len(emb_harus_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(emb_harus_micros)/len(emb_harus_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			5020059 µs
# Maximale Inferenzdauer: 			5026354 µs
# Durchschnittliche Inferenzdauer: 		5023484.98 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	5023.48498 µs
# Inferenzen pro Sekunde: 			199.06499252636362
# Inferenzen pro Sekunde (gerundet): 		199

# %% [markdown]
# ## 5.4 RFECV HARUS

# %%
# Sketch uses 306376 bytes (31%) of program storage space. Maximum is 983040 bytes.
# Global variables use 46744 bytes (17%) of dynamic memory, leaving 215400 bytes for local variables. Maximum is 262144 bytes.

# Sketch rfecv_harus_empty: 530 KB (543.548 Bytes)

rfecv_harus_micros = [
    4701750, 4700852, 4702333, 4702395, 4701065, 4702089, 4702861, 4703513, 4701666, 4704717, 
    4702157, 4699674, 4699513, 4703828, 4702722, 4702091, 4702272, 4702753, 4698738, 4701550, 
    4698320, 4698793, 4701136, 4701646, 4702530, 4702991, 4702407, 4703412, 4700023, 4703625, 
    4697633, 4700968, 4699969, 4703901, 4701213, 4701661, 4702619, 4703324, 4702134, 4703914, 
    4700404, 4702516, 4702691, 4700407, 4701685, 4700579, 4702130, 4702030, 4703219, 4699387 
]

print(f'Minimale Inferenzdauer: \t\t\t{min(rfecv_harus_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(rfecv_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(rfecv_harus_micros)/len(rfecv_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(rfecv_harus_micros)/len(rfecv_harus_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(rfecv_harus_micros)/len(rfecv_harus_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(rfecv_harus_micros)/len(rfecv_harus_micros))/1000))}')

# %% [markdown]
# ## 5.5 Emb SeMu

# %%
# Sketch uses 347976 bytes (35%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45144 bytes (17%) of dynamic memory, leaving 217000 bytes for local variables. Maximum is 262144 bytes.

# Sketch emb_semu_empty : 895 KB (916.818 Bytes)

emb_semu_micros = [
    3323842, 3306343, 3321784, 3307682, 3320630, 3293122, 3329152, 3304542, 3310440, 3306415, 
    3321928, 3307620, 3315317, 3309235, 3314730, 3309725, 3328284, 3304829, 3325457, 3316198, 
    3304507, 3308655, 3307082, 3310076, 3313605, 3320745, 3312220, 3313192, 3319446, 3308272, 
    3321901, 3323546, 3315318, 3296792, 3307075, 3315479, 3310396, 3310411, 3320082, 3309592, 
    3301838, 3303972, 3300467, 3312900, 3314229, 3315558, 3313428, 3301261, 3309369, 3320077
    ]

print(f'Minimale Inferenzdauer: \t\t\t{min(emb_semu_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(emb_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(emb_semu_micros)/len(emb_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(emb_semu_micros)/len(emb_semu_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(emb_semu_micros)/len(emb_semu_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(emb_semu_micros)/len(emb_semu_micros))/1000))}')
# Out:
# 50
# Minimale Inferenzdauer: 			3293122 µs
# Maximale Inferenzdauer: 			3329152 µs
# Durchschnittliche Inferenzdauer: 		3312375.32 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	3312.3753199999996 µs
# Inferenzen pro Sekunde: 			301.89815567156205
# Inferenzen pro Sekunde (gerundet): 		301

# %% [markdown]
# ## 5.6 RFECV SeMu

# %%
# Sketch uses 278152 bytes (28%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45160 bytes (17%) of dynamic memory, leaving 216984 bytes for local variables. Maximum is 262144 bytes.

# Sketch rfecv_semu_empty: 764 KB (783.080 Bytes)

rfecv_semu_micros = [
    1841481, 1840649, 1833942, 1840723, 1843252, 1845083, 1840018, 1841120, 1846551, 1839776, 
    1839222, 1845549, 1834419, 1840556, 1832704, 1850778, 1838563, 1847320, 1833791, 1833306, 
    1836294, 1841709, 1843079, 1826890, 1842617, 1839613, 1837116, 1842182, 1834587, 1845312, 
    1840245, 1843591, 1842993, 1841243, 1838613, 1839811, 1834891, 1845821, 1834049, 1839378, 
    1844010, 1839489, 1849294, 1841655, 1840761, 1845060, 1831838, 1843512, 1838916, 1839356
    ]

print(len(rfecv_semu_micros))

print(f'Minimale Inferenzdauer: \t\t\t{min(rfecv_semu_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(rfecv_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(rfecv_semu_micros)/len(rfecv_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(rfecv_semu_micros)/len(rfecv_semu_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(rfecv_semu_micros)/len(rfecv_semu_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(rfecv_semu_micros)/len(rfecv_semu_micros))/1000))}')
# Out:
# 50
# Minimale Inferenzdauer: 			1826890 µs
# Maximale Inferenzdauer: 			1850778 µs
# Durchschnittliche Inferenzdauer: 		1840254.56 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	1840.25456 µs
# Inferenzen pro Sekunde: 			543.4030822344491
# Inferenzen pro Sekunde (gerundet): 		543

# %% [markdown]
# # 6 Performance Feature Selection

# %% [markdown]
# ## 6.1 AGMP

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

agmp_emb_scores = pd.read_csv("datasets/port-scores/fs_emb_agmp_scores.csv")
ypred = agmp_emb_scores["class"]
ytrue = pd.read_csv("datasets/agmp/ytest.csv")['Activity']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.balanced_accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 88, 671, 4671, 9

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   0.115942  0.907216  0.205607        97
#   1: walking   0.998077  0.874392  0.932149      5342
#
#     accuracy                       0.874977      5439
#    macro avg   0.557009  0.890804  0.568878      5439
# weighted avg   0.982345  0.874977  0.919192      5439
#
# 0.8908040542366078
#
# Genauigkeit: 0.874977
# Präzision (eigene Berechnung): 0.115942
# Sensitivität: 0.907216
# Spezifität: 0.874392
# NPV: 0.998077
# F1-Score: 0.874977
# F1-Score (eigene Berechnung): 0.205607

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

agmp_rfecv_scores = pd.read_csv("datasets/port-scores/fs_rfecv_agmp_scores.csv")
ypred = agmp_rfecv_scores["class"]
ytrue = pd.read_csv("datasets/agmp/ytest.csv")['Activity']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.balanced_accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 90, 968, 4374, 7

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   0.085066  0.927835  0.155844        97
#   1: walking   0.998402  0.818794  0.899722      5342
#
#     accuracy                       0.820739      5439
#    macro avg   0.541734  0.873315  0.527783      5439
# weighted avg   0.982114  0.820739  0.886456      5439
#
# 0.873314755275255
#
# Genauigkeit: 0.820739
# Präzision (eigene Berechnung): 0.085066
# Sensitivität: 0.927835
# Spezifität: 0.818794
# NPV: 0.998402
# F1-Score: 0.820739
# F1-Score (eigene Berechnung): 0.155844

# %% [markdown]
# ## 6.2 Harus

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

harus_emb_scores = pd.read_csv("datasets/port-scores/fs_emb_harus_scores.csv")
ypred = pd.Series(list(harus_emb_scores["class"]))
ytrue = pd.read_csv("datasets/harus/ytest.csv")['label']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.accuracy_score(ytrue,ypred))

def calculate_confusion_counts(ycompare, values):
    sumtp, sumfp, sumtn, sumfn = 0, 0, 0, 0
    for val in values:
        tp = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] == val)].shape[0]
        fn = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] != val)].shape[0]
        tn = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] != val)].shape[0]
        fp = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] == val)].shape[0]

        sumtp += tp
        sumfp += fp
        sumtn += tn
        sumfn += fn

        print(f'{val}: TP {tp}, FP {fp}, TN {tn}, FN {fn}')
        
    print(f'Total: TP {sumtp}, FP {sumfp}, TN {sumtn}, FN {sumfn}')

ycompare = pd.concat([ytrue,ypred],axis=1)
ycompare = ycompare.rename(columns={"label": "true", 0: "predicted"})
print(ycompare.columns)
calculate_confusion_counts(ycompare, [0,1,2,3,4,5])

sumtp, sumfp, sumtn, sumfn = 1735, 16, 8739, 16

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   0.993127  0.986348  0.989726       293
#   1: walking   0.988679  0.996198  0.992424       263
#
#    micro avg   0.991007  0.991007  0.991007       556
#    macro avg   0.990903  0.991273  0.991075       556
# weighted avg   0.991023  0.991007  0.991002       556
#
# 0.9908623643632211
# Index(['true', 'predicted'], dtype='object')
# 0: TP 289, FP 2, TN 1456, FN 4
# 1: TP 262, FP 3, TN 1485, FN 1
# 2: TP 237, FP 3, TN 1509, FN 2
# 3: TP 298, FP 5, TN 1444, FN 4
# 4: TP 319, FP 3, TN 1424, FN 5
# 5: TP 330, FP 0, TN 1421, FN 0
# Total: TP 1735, FP 16, TN 8739, FN 16
#
# Genauigkeit: 0.990862
# Präzision (eigene Berechnung): 0.990862
# Sensitivität: 0.990862
# Spezifität: 0.998172
# NPV: 0.998172
# F1-Score: 0.990862
# F1-Score (eigene Berechnung): 0.990862

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

harus_rfecv_scores = pd.read_csv("datasets/port-scores/fs_rfecv_harus_scores.csv")
ypred = pd.Series(list(harus_rfecv_scores["class"]))
ytrue = pd.read_csv("datasets/harus/ytest.csv")['label']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.accuracy_score(ytrue,ypred))

def calculate_confusion_counts(ycompare, values):
    sumtp, sumfp, sumtn, sumfn = 0, 0, 0, 0
    for val in values:
        tp = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] == val)].shape[0]
        fn = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] != val)].shape[0]
        tn = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] != val)].shape[0]
        fp = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] == val)].shape[0]

        sumtp += tp
        sumfp += fp
        sumtn += tn
        sumfn += fn

        print(f'{val}: TP {tp}, FP {fp}, TN {tn}, FN {fn}')
        
    print(f'Total: TP {sumtp}, FP {sumfp}, TN {sumtn}, FN {sumfn}')

ycompare = pd.concat([ytrue,ypred],axis=1)
ycompare = ycompare.rename(columns={"label": "true", 0: "predicted"})
print(ycompare.columns)
calculate_confusion_counts(ycompare, [0,1,2,3,4,5])

sumtp, sumfp, sumtn, sumfn = 1734, 17, 8738, 17

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   0.993151  0.989761  0.991453       293
#   1: walking   0.992453  1.000000  0.996212       263
#
#    micro avg   0.992819  0.994604  0.993711       556
#    macro avg   0.992802  0.994881  0.993833       556
# weighted avg   0.992821  0.994604  0.993704       556
#
# 0.9902912621359223
# Index(['true', 'predicted'], dtype='object')
# 0: TP 290, FP 2, TN 1456, FN 3
# 1: TP 263, FP 2, TN 1486, FN 0
# 2: TP 236, FP 3, TN 1509, FN 3
# 3: TP 296, FP 5, TN 1444, FN 6
# 4: TP 319, FP 5, TN 1422, FN 5
# 5: TP 330, FP 0, TN 1421, FN 0
# Total: TP 1734, FP 17, TN 8738, FN 17
#
# Genauigkeit: 0.990291
# Präzision (eigene Berechnung): 0.990291
# Sensitivität: 0.990291
# Spezifität: 0.998058
# NPV: 0.998058
# F1-Score: 0.990291
# F1-Score (eigene Berechnung): 0.990291

# %% [markdown]
# ## 6.3 Secondary Mushroom

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

semu_emb_scores = pd.read_csv("datasets/port-scores/fs_emb_semu_scores.csv")
ypred = semu_emb_scores["class"]
ytrue = pd.read_csv("datasets/semu/ytest.csv")['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 4621, 0, 5761, 0

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   1.000000  1.000000  1.000000      4621
#   1: walking   1.000000  1.000000  1.000000      5761
#
#     accuracy                       1.000000     10382
#    macro avg   1.000000  1.000000  1.000000     10382
# weighted avg   1.000000  1.000000  1.000000     10382
#
# 1.0
#
# Genauigkeit: 1.000000
# Präzision (eigene Berechnung): 1.000000
# Sensitivität: 1.000000
# Spezifität: 1.000000
# NPV: 1.000000
# F1-Score: 1.000000
# F1-Score (eigene Berechnung): 1.000000

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

semu_rfecv_scores = pd.read_csv("datasets/port-scores/fs_rfecv_semu_scores.csv")
ypred = semu_rfecv_scores["class"]
ytrue = pd.read_csv("datasets/semu/ytest.csv")['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.balanced_accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 4621, 0, 5761, 0

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   1.000000  1.000000  1.000000      4621
#   1: walking   1.000000  1.000000  1.000000      5761
#
#     accuracy                       1.000000     10382
#    macro avg   1.000000  1.000000  1.000000     10382
# weighted avg   1.000000  1.000000  1.000000     10382
#
# 1.0

# %% [markdown]
# # 7 Zeiten Hyperparameteroptimierung

# %% [markdown]
# ## 7.1 AGMP

# %%
# Sketch uses 112200 bytes (11%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45592 bytes (17%) of dynamic memory, leaving 216552 bytes for local variables. Maximum is 262144 bytes.

# hyper_agmp_empty: 61,999 KB (63.487 Bytes)

hyper_agmp_micros = [        
    590789, 590335, 591238, 590191, 587139, 591005, 590613, 591591, 591504, 591380, 
    588537, 589490, 592895, 590509, 588858, 591346, 589407, 590551, 590634, 589912, 
    592242, 591228, 590116, 591007, 591931, 590196, 589643, 590598, 591443, 592169, 
    589373, 591459, 589166, 586939, 588980, 590417, 590904, 590366, 590032, 591749, 
    590580, 593025, 590637, 590938, 591933, 592178, 590585, 591961, 589600, 590725
]

print(f'Minimale Inferenzdauer: \t\t\t{min(hyper_agmp_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(hyper_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(hyper_agmp_micros)/len(hyper_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(hyper_agmp_micros)/len(hyper_agmp_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(hyper_agmp_micros)/len(hyper_agmp_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(hyper_agmp_micros)/len(hyper_agmp_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			586939 µs
# Maximale Inferenzdauer: 			593025 µs
# Durchschnittliche Inferenzdauer: 		590600.88 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	590.60088 µs
# Inferenzen pro Sekunde: 			1693.1908398104656
# Inferenzen pro Sekunde (gerundet): 		1693

# %% [markdown]
# ## 7.2 HARUS

# %%
# Sketch uses 340616 bytes (34%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45592 bytes (17%) of dynamic memory, leaving 216552 bytes for local variables. Maximum is 262144 bytes.

# Sketch hyper_harus_empty: 566,866 KB (580.471 Bytes)

hyper_harus_micros = [    
    6328093, 6326482, 6329033, 6328402, 6327915, 6327737, 6328151, 6330111, 6327538, 6330590, 
    6328979, 6329507, 6330089, 6331050, 6331692, 6330488, 6328915, 6329535, 6330374, 6330550, 
    6330424, 6331029, 6330528, 6331092, 6330639, 6326641, 6328389, 6330877, 6330882, 6330753, 
    6330442, 6329809, 6330203, 6330413, 6327215, 6328520, 6330678, 6330427, 6330380, 6330731, 
    6331106, 6330334, 6330194, 6327355, 6331752, 6330482, 6330241, 6331094, 6329340, 6330727
]

print(f'Minimale Inferenzdauer: \t\t\t{min(hyper_harus_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(hyper_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(hyper_harus_micros)/len(hyper_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(hyper_harus_micros)/len(hyper_harus_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(hyper_harus_micros)/len(hyper_harus_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(hyper_harus_micros)/len(hyper_harus_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			6326482 µs
# Maximale Inferenzdauer: 			6331752 µs
# Durchschnittliche Inferenzdauer: 		6329758.56 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	6329.758559999999 µs
# Inferenzen pro Sekunde: 			157.98390894707367
# Inferenzen pro Sekunde (gerundet): 		157

# %% [markdown]
# ## 7.3 SeMu

# %%
# Sketch uses 167240 bytes (17%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45592 bytes (17%) of dynamic memory, leaving 216552 bytes for local variables. Maximum is 262144 bytes.

# Sketch hyper_semu_empty: 348,75 KB (357.120 Bytes)

hyper_semu_micros = [
    626226, 626391, 625880, 626316, 623889, 625766, 625731, 626499, 627761, 622045, 
    623239, 626210, 624888, 627446, 626299, 627802, 625038, 624761, 623983, 625856, 
    625018, 626188, 625070, 625484, 625759, 628487, 623923, 626600, 625121, 626953, 
    622936, 625739, 624534, 627439, 627392, 625978, 627435, 625532, 626797, 624579, 
    622722, 624960, 625234, 624529, 624108, 625772, 627729, 627370, 626007, 625867, 
]

print(f'Minimale Inferenzdauer: \t\t\t{min(hyper_semu_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(hyper_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(hyper_semu_micros)/len(hyper_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(hyper_semu_micros)/len(hyper_semu_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(hyper_semu_micros)/len(hyper_semu_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(hyper_semu_micros)/len(hyper_semu_micros))/1000))}')
# Out:
# Minimale Inferenzdauer: 			622045 µs
# Maximale Inferenzdauer: 			628487 µs
# Durchschnittliche Inferenzdauer: 		625665.76 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	625.66576 µs
# Inferenzen pro Sekunde: 			1598.2974679643648
# Inferenzen pro Sekunde (gerundet): 		1598

# %% [markdown]
# # 8 Performance Hyperparameteroptimierung

# %% [markdown]
# ## 8.1 AGMP

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm


agmp_hyper_scores = pd.read_csv("datasets/port-scores/hyper_agmp_scores.csv")
ypred = agmp_hyper_scores["class"]
ytrue = pd.read_csv("datasets/agmp/ytest.csv")['Activity']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,labels=[0,1], target_names=['0: standing','1: walking'], digits=6))
print(skm.balanced_accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 90, 700, 4642, 7

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.balanced_accuracy_score(ytrue,ypred)

print(f'\nBalancierte Genauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#  0: standing   0.113924  0.927835  0.202931        97
#   1: walking   0.998494  0.868963  0.929236      5342
#
#     accuracy                       0.870013      5439
#    macro avg   0.556209  0.898399  0.566084      5439
# weighted avg   0.982719  0.870013  0.916283      5439
#
# 0.8983989933883213
#
# Balancierte Genauigkeit: 0.898399
# Präzision (eigene Berechnung): 0.113924
# Sensitivität: 0.927835
# Spezifität: 0.868963
# NPV: 0.998494
# F1-Score: 0.870013
# F1-Score (eigene Berechnung): 0.202931

# %% [markdown]
# ## 8.2 HARUS

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

harus_hyper_scores = pd.read_csv("datasets/port-scores/hyper_harus_scores.csv")
ypred = pd.Series(list(harus_hyper_scores["class"]))
ytrue = pd.read_csv("datasets/harus/ytest.csv")['label']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

def calculate_confusion_counts(ycompare, values):
    sumtp, sumfp, sumtn, sumfn = 0, 0, 0, 0
    for val in values:
        tp = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] == val)].shape[0]
        fn = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] != val)].shape[0]
        tn = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] != val)].shape[0]
        fp = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] == val)].shape[0]

        sumtp += tp
        sumfp += fp
        sumtn += tn
        sumfn += fn

        print(f'{val}: TP {tp}, FP {fp}, TN {tn}, FN {fn}')
        
    print(f'Total: TP {sumtp}, FP {sumfp}, TN {sumtn}, FN {sumfn}')

ycompare = pd.concat([ytrue,ypred],axis=1)
ycompare = ycompare.rename(columns={"label": "true", 0: "predicted"})
calculate_confusion_counts(ycompare, [0,1,2,3,4,5])

sumtp, sumfp, sumtn, sumfn = 1733, 18, 8737, 18

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#            0   0.989761  0.989761  0.989761       293
#            1   0.988722  1.000000  0.994329       263
#            2   0.987342  0.979079  0.983193       239
#            3   0.983444  0.983444  0.983444       302
#            4   0.987616  0.984568  0.986090       324
#            5   1.000000  1.000000  1.000000       330
#
#     accuracy                       0.989720      1751
#    macro avg   0.989481  0.989475  0.989469      1751
# weighted avg   0.989718  0.989720  0.989711      1751
#
# 0.9897201599086236
# 0: TP 290, FP 3, TN 1455, FN 3
# 1: TP 263, FP 3, TN 1485, FN 0
# 2: TP 234, FP 3, TN 1509, FN 5
# 3: TP 297, FP 5, TN 1444, FN 5
# 4: TP 319, FP 4, TN 1423, FN 5
# 5: TP 330, FP 0, TN 1421, FN 0
# Total: TP 1733, FP 18, TN 8737, FN 18
#
# Genauigkeit: 0.989720
# Präzision (eigene Berechnung): 0.989720
# Sensitivität: 0.989720
# Spezifität: 0.997944
# NPV: 0.997944
# F1-Score: 0.989720
# ...

# %% [markdown]
# ## 8.3 Secondary Mushroom

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as skm

semu_hyper_scores = pd.read_csv("datasets/port-scores/hyper_semu_scores.csv")
ypred = semu_hyper_scores["class"]
ytrue = pd.read_csv("datasets/semu/ytest.csv")['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 4620, 0, 5761, 1

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#            0   1.000000  0.999784  0.999892      4621
#            1   0.999826  1.000000  0.999913      5761
#
#     accuracy                       0.999904     10382
#    macro avg   0.999913  0.999892  0.999903     10382
# weighted avg   0.999904  0.999904  0.999904     10382
#
# 0.9999036794451936
#
# Genauigkeit: 0.999904
# Präzision (eigene Berechnung): 1.000000
# Sensitivität: 0.999784
# Spezifität: 1.000000
# NPV: 0.999826
# F1-Score: 0.999904
# F1-Score (eigene Berechnung): 0.999892

# %% [markdown]
# # 9 Quantisierung

# %% [markdown]
# ## 9.1 AGMP

# %%
ytrue = pd.read_csv("datasets/agmp/ytest.csv")['Activity']
ypred = pd.read_csv('datasets/port-scores/quant_agmp_scores.csv')['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

sumtp, sumfp, sumtn, sumfn = 85, 618, 4724, 12

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.balanced_accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')

quant_agmp_micros = [
    1203442, 1202679, 1202753, 1202881, 1202524, 1202715, 1202453, 1202781, 1202594, 1202538, 
    1202521, 1202820, 1202833, 1202410, 1202294, 1202410, 1201837, 1201963, 1201976, 1202086, 
    1202239, 1202281, 1202704, 1202757, 1202546, 1202749, 1202859, 1202638, 1202797, 1202536, 
    1202671, 1202578, 1202564, 1202726, 1202412, 1202592, 1202607, 1202758, 1202540, 1202473, 
    1202708, 1202524, 1202810, 1202560, 1202532, 1202481, 1202726, 1202786, 1202682, 1202865
]

print(f'Minimale Inferenzdauer: \t\t\t{min(quant_agmp_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(quant_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(quant_agmp_micros)/len(quant_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(quant_agmp_micros)/len(quant_agmp_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(quant_agmp_micros)/len(quant_agmp_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(quant_agmp_micros)/len(quant_agmp_micros))/1000))}')
# Out:
#               precision    recall  f1-score   support
#
#            0   0.120910  0.876289  0.212500        97
#            1   0.997466  0.884313  0.937488      5342
#
#     accuracy                       0.884170      5439
#    macro avg   0.559188  0.880301  0.574994      5439
# weighted avg   0.981834  0.884170  0.924558      5439
#
# 0.8841698841698842
#
# Genauigkeit: 0.880301
# Präzision (eigene Berechnung): 0.120910
# Sensitivität: 0.876289
# Spezifität: 0.884313
# NPV: 0.997466
# F1-Score: 0.884170
# F1-Score (eigene Berechnung): 0.212500
#
# Minimale Inferenzdauer: 			1201837 µs
# Maximale Inferenzdauer: 			1203442 µs
# Durchschnittliche Inferenzdauer: 		1202584.22 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	1202.58422 µs
# Inferenzen pro Sekunde: 			831.5425925013385
# Inferenzen pro Sekunde (gerundet): 		831

# %% [markdown]
# |Kennzahlen|AGMP|
# |------|-|
# |max Baumtiefe              |1|
# |Anzahl Schätzer            |1314|
# |Anzahl Knoten              |3942|
# |Programmspeicher           |118,383 KB|
# |(Sketch Größe)             |160,707 KB|
# |Geschwindigkeit            |1202.58 ms|
# |IPM                        |831|
# | | |
# | | |
# |Balancierte Genauigkeit    |0.884170|
# |Präzision                  |0.120910|
# |Sensitivität               |0.876289|
# |Spezifität                 |0.884313|
# |NPW                        |0.997466|
# |F-Maß                      |0.212500|

# %% [markdown]
# ## 9.2 HARUS

# %%
ytrue = pd.read_csv("datasets/harus/ytest.csv")['label']
ypred = pd.read_csv('datasets/port-scores/quant_harus_scores.csv')['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

quant_harus_micros = [    
    3506969, 3503771, 3503182, 3504901, 3504175, 3504574, 3505808, 3504485, 3504267, 3502778, 
    3503351, 3504196, 3504978, 3503781, 3503710, 3504926, 3504210, 3505288, 3503123, 3504153, 
    3503778, 3504874, 3504733, 3505922, 3505507, 3503651, 3503502, 3505156, 3506308, 3505743, 
    3505223, 3503420, 3521346, 3521887, 3523406, 3522010, 3522084, 3521760, 3521214, 3521899, 
    3519716, 3519868, 3520736, 3522304, 3522111, 3520730, 3522912, 3522282, 3520389, 3519879
]

print(f'Minimale Inferenzdauer: \t\t\t{min(quant_harus_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(quant_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(quant_harus_micros)/len(quant_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(quant_harus_micros)/len(quant_harus_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(quant_harus_micros)/len(quant_harus_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(quant_harus_micros)/len(quant_harus_micros))/1000))}')

sumtp, sumfp, sumtn, sumfn = 1729, 22, 8733, 22

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')
# Out:
#               precision    recall  f1-score   support
#
#            0   0.993151  0.989761  0.991453       293
#            1   0.992453  1.000000  0.996212       263
#            2   0.987448  0.987448  0.987448       239
#            3   0.976667  0.970199  0.973422       302
#            4   0.975385  0.978395  0.976888       324
#            5   1.000000  1.000000  1.000000       330
#
#     accuracy                       0.987436      1751
#    macro avg   0.987517  0.987634  0.987570      1751
# weighted avg   0.987428  0.987436  0.987427      1751
#
# 0.9874357509994289
# Minimale Inferenzdauer: 			3502778 µs
# Maximale Inferenzdauer: 			3523406 µs
# Durchschnittliche Inferenzdauer: 		3510619.52 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	3510.61952 µs
# Inferenzen pro Sekunde: 			284.85000846802103
# Inferenzen pro Sekunde (gerundet): 		284
#
# Genauigkeit: 0.987436
# Präzision (eigene Berechnung): 0.987436
# Sensitivität: 0.987436
# Spezifität: 0.997487
# ...

# %% [markdown]
# |Kennzahlen|HARUS|
# |------|-|
# |max Baumtiefe|4|
# |Anzahl Schätzer|1164|
# |Anzahl Knoten|9694|
# |Programmspeicher|241,258 KB|
# |(Sketch Größe)|490,377 KB|
# |Geschwindigkeit|3510.62 ms|
# |IPM|284|
# | | |
# | | |
# |Genauigkeit|0.987436|
# |Präzision|0.987436|
# |Sensitivität|0.987436|
# |Spezifität|0.997487|
# |NPW|0.997487|
# |F-Maß|0.987436|

# %% [markdown]
# ## 9.3 Secondary Mushroom

# %%
ytrue = pd.read_csv("datasets/semu/ytest.csv")['class']
ypred = pd.read_csv('datasets/port-scores/quant_semu_scores.csv')['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

# Sketch uses 167240 bytes (17%) of program storage space. Maximum is 983040 bytes.
# Global variables use 45592 bytes (17%) of dynamic memory, leaving 216552 bytes for local variables. Maximum is 262144 bytes.

# Sketch hyper_semu_empty: 348,75 KB (357.120 Bytes)

quant_semu_micros = [
    2017538, 2025233, 2018732, 2024215, 2013635, 2017288, 2019447, 2018659, 2023557, 2020758,
    2031095, 2021817, 2014095, 2018091, 2021222, 2019332, 2024522, 2023107, 2019974, 2020115, 
    2019059, 2014504, 2018178, 2015916, 2024465, 2011156, 2017379, 2022017, 2019118, 2029710, 
    2018294, 2018586, 2020053, 2016364, 2021338, 2021014, 2019267, 2016169, 2026085, 2013057, 
    2021744, 2019162, 2013377, 2013389, 2021821, 2014690, 2013917, 2024214, 2021843, 2021162,
]

print(f'Minimale Inferenzdauer: \t\t\t{min(quant_semu_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(quant_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(quant_semu_micros)/len(quant_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(quant_semu_micros)/len(quant_semu_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(quant_semu_micros)/len(quant_semu_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(quant_semu_micros)/len(quant_semu_micros))/1000))}')
# Out:
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000      4621
#            1   1.000000  1.000000  1.000000      5761
#
#     accuracy                       1.000000     10382
#    macro avg   1.000000  1.000000  1.000000     10382
# weighted avg   1.000000  1.000000  1.000000     10382
#
# 1.0
# Minimale Inferenzdauer: 			2011156 µs
# Maximale Inferenzdauer: 			2031095 µs
# Durchschnittliche Inferenzdauer: 		2019589.6 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	2019.5896 µs
# Inferenzen pro Sekunde: 			495.15010376365575
# Inferenzen pro Sekunde (gerundet): 		495

# %% [markdown]
# |Kennzahlen|Semu|
# |------|-|
# |max Baumtiefe|7|
# |Anzahl Schätzer|551|
# |Anzahl Knoten|11621|
# |Programmspeicher|219,258 KB|
# |(Sketch Größe)|682,247 KB|
# |Geschwindigkeit|2019.58 ms|
# |IPM|495|
# | | |
# | | |
# |Genauigkeit|1|
# |Präzision|1|
# |Sensitivität|1|
# |Spezifität|1|
# |NPW|1|
# |F-Maß|1|

# %% [markdown]
# # 10 Kombiniert

# %% [markdown]
# ## 10.1 AGMP

# %%
ytrue = pd.read_csv("datasets/agmp/ytest.csv")['Activity']
ypred = pd.read_csv('datasets/port-scores/combined_agmp_scores.csv')['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))

sumtp, sumfp, sumtn, sumfn = 89,906,4436,8

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.balanced_accuracy_score(ytrue,ypred)

print(f'\nBalancierte Genauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')

quant_agmp_micros = [
    260011, 260071, 258623, 260291, 258128, 259512, 258769, 259327, 259460, 258893, 
    259225, 259173, 258504, 258792, 260233, 259682, 259140, 259092, 258734, 259558, 
    259029, 259212, 258219, 259102, 258419, 258957, 259359, 259201, 259413, 258459, 
    259132, 258893, 259290, 258377, 258775, 260265, 258790, 258395, 259725, 258350, 
    258677, 259131, 259020, 258100, 259766, 259341, 259923, 258551, 260317, 259891
]

print(f'Minimale Inferenzdauer: \t\t\t{min(quant_agmp_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(quant_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(quant_agmp_micros)/len(quant_agmp_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(quant_agmp_micros)/len(quant_agmp_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(quant_agmp_micros)/len(quant_agmp_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(quant_agmp_micros)/len(quant_agmp_micros))/1000))}')
# Out:
#               precision    recall  f1-score   support
#
#            0   0.089447  0.917526  0.163004        97
#            1   0.998200  0.830401  0.906601      5342
#
#     accuracy                       0.831954      5439
#    macro avg   0.543824  0.873963  0.534802      5439
# weighted avg   0.981993  0.831954  0.893340      5439
#
#
# Balancierte Genauigkeit: 0.873963
# Präzision (eigene Berechnung): 0.089447
# Sensitivität: 0.917526
# Spezifität: 0.830401
# NPV: 0.998200
# F1-Score: 0.831954
# F1-Score (eigene Berechnung): 0.163004
#
# Minimale Inferenzdauer: 			258100 µs
# Maximale Inferenzdauer: 			260317 µs
# Durchschnittliche Inferenzdauer: 		259145.94 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	259.14594 µs
# Inferenzen pro Sekunde: 			3858.8295074196417
# Inferenzen pro Sekunde (gerundet): 		3858

# %% [markdown]
# |Kennzahlen|AGMP|
# |------|-|
# |max Baumtiefe      |5|
# |Anzahl Schätzer    |48|
# |Anzahl Knoten      ||
# |Programmspeicher   |90,258 KB|
# |(Sketch Größe)     |16,8 KB|
# |Geschwindigkeit    |259.15 ms|
# |IPM                |3858|
# | | |
# | | |
# |Balan. Genauigkeit |0.873963|
# |Präzision          |0.089447|
# |Sensitivität       |0.917526|
# |Spezifität         |0.830401|
# |NPW                |0.998200|
# |F-Maß              |0.163004|

# %% [markdown]
# ## 10.2 HARUS

# %%
ytrue = pd.read_csv("datasets/harus/ytest.csv")['label']
ypred = pd.read_csv('datasets/port-scores/combined_harus_scores.csv')['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

def calculate_confusion_counts(ycompare, values):
    sumtp, sumfp, sumtn, sumfn = 0, 0, 0, 0
    for val in values:
        tp = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] == val)].shape[0]
        fn = ycompare[(ycompare["true"] == val) & (ycompare["predicted"] != val)].shape[0]
        tn = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] != val)].shape[0]
        fp = ycompare[(ycompare["true"] != val) & (ycompare["predicted"] == val)].shape[0]

        sumtp += tp
        sumfp += fp
        sumtn += tn
        sumfn += fn

        print(f'{val}: TP {tp}, FP {fp}, TN {tn}, FN {fn}')
        
    print(f'Total: TP {sumtp}, FP {sumfp}, TN {sumtn}, FN {sumfn}')

ycompare = pd.concat([ytrue,ypred],axis=1)
ycompare = ycompare.rename(columns={"label": "true", "class": "predicted"})
calculate_confusion_counts(ycompare, [0,1,2,3,4,5])

sumtp, sumfp, sumtn, sumfn = 1735, 16, 8739, 16

prec = sumtp/(sumtp + sumfp)
sens = sumtp/(sumtp + sumfn)
spec = sumtn/(sumtn + sumfp)
npv = sumtn/(sumtn + sumfn)
fscore = skm.f1_score(ytrue,ypred,average="micro")
fscoremine = 2 * ((prec * sens) / (prec + sens))
acc = skm.accuracy_score(ytrue,ypred)

print(f'\nGenauigkeit: {("%.6f" % acc)}')
print(f'Präzision (eigene Berechnung): {("%.6f" % prec)}')
print(f'Sensitivität: {("%.6f" % sens)}')
print(f'Spezifität: {("%.6f" % spec)}')
print(f'NPV: {("%.6f" % npv)}')
print(f'F1-Score: {("%.6f" % fscore)}')
print(f'F1-Score (eigene Berechnung): {("%.6f" % fscoremine)}\n')

quant_harus_micros = [    
    4759949, 4759819, 4757385, 4763125, 4760124, 4758822, 4760559, 4759207, 4759714, 4760748, 
    4759086, 4760171, 4761395, 4758724, 4761393, 4759267, 4759032, 4758887, 4757781, 4758688, 
    4760377, 4760172, 4759471, 4758009, 4759106, 4757280, 4759152, 4757938, 4758389, 4761178, 
    4760710, 4759615, 4760404, 4760125, 4760764, 4758568, 4756514, 4758362, 4760385, 4760355, 
    4761320, 4759274, 4761466, 4759597, 4762290, 4758934, 4760017, 4762661, 4758667, 4760036,
]

print(f'Minimale Inferenzdauer: \t\t\t{min(quant_harus_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(quant_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(quant_harus_micros)/len(quant_harus_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(quant_harus_micros)/len(quant_harus_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(quant_harus_micros)/len(quant_harus_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(quant_harus_micros)/len(quant_harus_micros))/1000))}')
# Out:
#               precision    recall  f1-score   support
#
#            0   0.996552  0.986348  0.991424       293
#            1   0.985019  1.000000  0.992453       263
#            2   0.987448  0.987448  0.987448       239
#            3   0.986711  0.983444  0.985075       302
#            4   0.987654  0.987654  0.987654       324
#            5   1.000000  1.000000  1.000000       330
#
#     accuracy                       0.990862      1751
#    macro avg   0.990564  0.990816  0.990676      1751
# weighted avg   0.990883  0.990862  0.990859      1751
#
# 0.9908623643632211
# 0: TP 289, FP 1, TN 1457, FN 4
# 1: TP 263, FP 4, TN 1484, FN 0
# 2: TP 236, FP 3, TN 1509, FN 3
# 3: TP 297, FP 4, TN 1445, FN 5
# 4: TP 320, FP 4, TN 1423, FN 4
# 5: TP 330, FP 0, TN 1421, FN 0
# Total: TP 1735, FP 16, TN 8739, FN 16
#
# Genauigkeit: 0.990862
# Präzision (eigene Berechnung): 0.990862
# Sensitivität: 0.990862
# Spezifität: 0.998172
# NPV: 0.998172
# F1-Score: 0.990862
# ...

# %% [markdown]
# |Kennzahlen|HARUS|
# |------|-|
# |max Baumtiefe      |3|
# |Anzahl Schätzer    |1494|
# |Anzahl Knoten      |14866|
# |Programmspeicher   |267,133 KB|
# |(Sketch Größe)     |522,390 KB|
# |Geschwindigkeit    |4759.70 ms|
# |IPM                |210|
# | | |
# | | |
# |Genauigkeit        |0,990862|
# |Präzision          |0.990862|
# |Sensitivität       |0.990862|
# |Spezifität         |0.998172|
# |NPW                |0.998172|
# |F-Maß              |0.990862|

# %% [markdown]
# ## 10.3 Secondary Mushroom

# %%
ytrue = pd.read_csv("datasets/semu/ytest.csv")['class']
ypred = pd.read_csv('datasets/port-scores/combined_semu_scores.csv')['class']

skm.ConfusionMatrixDisplay.from_predictions(ytrue,ypred, cmap="Blues" ,values_format='d')
print(skm.classification_report(ytrue,ypred,digits=6))
print(skm.accuracy_score(ytrue,ypred))

quant_semu_micros = [
    2220036, 2230473, 2231516, 2223097, 2223746, 2215674, 2223259, 2227886, 2228343, 2221318, 
    2223912, 2224832, 2224763, 2225281, 2227399, 2218346, 2223974, 2222929, 2223797, 2218095, 
    2225476, 2218256, 2213552, 2215240, 2225173, 2224345, 2212219, 2227615, 2223298, 2219478, 
    2222513, 2215302, 2223628, 2221753, 2223471, 2220661, 2214236, 2222352, 2223799, 2224418, 
    2225461, 2217750, 2223948, 2227275, 2223567, 2225975, 2219451, 2219292, 2225145, 2215287
]

print(f'Minimale Inferenzdauer: \t\t\t{min(quant_semu_micros)} µs')
print(f'Maximale Inferenzdauer: \t\t\t{max(quant_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer: \t\t{sum(quant_semu_micros)/len(quant_semu_micros)} µs')
print(f'Durchschnittliche Inferenzdauer pro Instanz: \t{(sum(quant_semu_micros)/len(quant_semu_micros))/1000} µs')
print(f'Inferenzen pro Sekunde: \t\t\t{1000000/((sum(quant_semu_micros)/len(quant_semu_micros))/1000)}')
print(f'Inferenzen pro Sekunde (gerundet): \t\t{int(1000000/((sum(quant_semu_micros)/len(quant_semu_micros))/1000))}')
# Out:
#               precision    recall  f1-score   support
#
#            0   1.000000  1.000000  1.000000      4621
#            1   1.000000  1.000000  1.000000      5761
#
#     accuracy                       1.000000     10382
#    macro avg   1.000000  1.000000  1.000000     10382
# weighted avg   1.000000  1.000000  1.000000     10382
#
# 1.0
# Minimale Inferenzdauer: 			2212219 µs
# Maximale Inferenzdauer: 			2231516 µs
# Durchschnittliche Inferenzdauer: 		2222372.24 µs
# Durchschnittliche Inferenzdauer pro Instanz: 	2222.37224 µs
# Inferenzen pro Sekunde: 			449.96962345066004
# Inferenzen pro Sekunde (gerundet): 		449

# %% [markdown]
# |Kennzahlen|SeMu|
# |------|-|
# |max Baumtiefe      |5|
# |Anzahl Schätzer    |499|
# |Anzahl Knoten      |12187|
# |Programmspeicher   |218,445 KB|
# |(Sketch Größe)     |460,168 KB|
# |Geschwindigkeit    |2222.37 ms|
# |IPM                |449|
# | | |
# | | |
# |Genauigkeit        |1,0|
# |Präzision          |1,0|
# |Sensitivität       |1,0|
# |Spezifität         |1,0|
# |NPW                |1,0|
# |F-Maß              |1,0|
