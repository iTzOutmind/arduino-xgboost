# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Listen mit Kennzahlen erstellen

# %% [markdown]
# ## Kennzahlen nach Modell und Methode

# %%
agmp_base = [
    0.875708, # bAcc
    0.211854, # F-Score
    185.695, # Size in KB
    4062.77, # Speed
    3942 # Nodes
]
harus_base = [
    0.986865, # Acc
    0.986865, # F-Score
    303.383, # Size in KB
    4801.25, # Speed
    9694 # Nodes
]
semu_base = [
    1.000000, # Acc
    1.000000, # F-Score
    295.883, # Size in KB
    2957.54, # Speed
    11621 # Nodes
]
agmp_fse = [
    0.890804, # bAcc
    0.115942, # F-Score
    123.820, # Size in KB
    1725.34, # Speed
    1623 # Nodes
]
agmp_rfecv = [
    0.820739, # bAcc
    0.155844, # F-Score
    109.383, # Size in KB
    1086.19, # Speed
    1002 # Nodes
]
harus_fse = [
    0.990862, # Acc
    0.990862, # F-Score
    279.320, # Size in KB
    5023.48, # Speed
    8860 # Nodes
]
harus_rfecv = [
    0.990291, # Acc
    0.990291, # F-Score
    271.508, # Size in KB
    3312.38, # Speed
    9624 # Nodes
]
semu_fse = [
    1.000000,
    1.000000,
    339.633,
    3312.37,
    14306
]
semu_rfecv = [
    1.000000,
    1.000000,
    271.508,
    1840.25,
    10338
]
agmp_hyper = [
    0.898399,
    0.202931,
    109.570,
    590.60,
    1209
]
harus_hyper = [
    0.989720,
    0.989720,
    332.633,
    6329.76,
    15196
]
semu_hyper = [
    0.999904,
    0.999892,
    163.320,
    625.67,
    7477    
]
agmp_quant = [
    0.884170,
    0.212500,
    118.383,
    1202.58,
    3942
]
harus_quant = [
    0.987436,
    0.987436,
    241.258,
    3510.62,
    9694
]
semu_quant = [
    1.000000,
    1.000000,
    219.258,
    2019.58,
    11621
]
agmp_comb = [
    0.873963,
    0.163004,
    90.258,
    259.15,
    690
]
harus_comb = [
    0.990862,
    0.990862,
    267.133,
    4759.70,
    14866
]
semu_comb = [
    1.000000,
    1.000000,
    128.445,
    2222.37,
    12187
]

# %% [markdown]
# ## Kennzahlen nach Modell und Metrik

# %%
agmp_accs = [
    agmp_base[0],
    agmp_fse[0],
    agmp_rfecv[0],
    agmp_hyper[0],
    agmp_quant[0],
    agmp_comb[0]
]
agmp_fscores = [
    agmp_base[1],
    agmp_fse[1],
    agmp_rfecv[1],
    agmp_hyper[1],
    agmp_quant[1],
    agmp_comb[1]
]
agmp_sizes = [
    agmp_base[2],
    agmp_fse[2],
    agmp_rfecv[2],
    agmp_hyper[2],
    agmp_quant[2],
    agmp_comb[2]
]
agmp_speeds = [
    agmp_base[3],
    agmp_fse[3],
    agmp_rfecv[3],
    agmp_hyper[3],
    agmp_quant[3],
    agmp_comb[3]
]
agmp_nodes = [
    agmp_base[4],
    agmp_fse[4],
    agmp_rfecv[4],
    agmp_hyper[4],
    agmp_quant[4],
    agmp_comb[4]
]
harus_accs = [
    harus_base[0],
    harus_fse[0],
    harus_rfecv[0],
    harus_hyper[0],
    harus_quant[0],
    harus_comb[0]
]
harus_fscores = [
    harus_base[1],
    harus_fse[1],
    harus_rfecv[1],
    harus_hyper[1],
    harus_quant[1],
    harus_comb[1]
]
harus_sizes = [
    harus_base[2],
    harus_fse[2],
    harus_rfecv[2],
    harus_hyper[2],
    harus_quant[2],
    harus_comb[2]
]
harus_speeds = [
    harus_base[3],
    harus_fse[3],
    harus_rfecv[3],
    harus_hyper[3],
    harus_quant[3],
    harus_comb[3]
]
harus_nodes = [
    harus_base[4],
    harus_fse[4],
    harus_rfecv[4],
    harus_hyper[4],
    harus_quant[4],
    harus_comb[4]
]
semu_accs = [
    semu_base[0],
    semu_fse[0],
    semu_rfecv[0],
    semu_hyper[0],
    semu_quant[0],
    semu_comb[0]
]
semu_fscores = [
    semu_base[1],
    semu_fse[1],
    semu_rfecv[1],
    semu_hyper[1],
    semu_quant[1],
    semu_comb[1]
]
semu_sizes = [
    semu_base[2],
    semu_fse[2],
    semu_rfecv[2],
    semu_hyper[2],
    semu_quant[2],
    semu_comb[2]
]
semu_speeds = [
    semu_base[3],
    semu_fse[3],
    semu_rfecv[3],
    semu_hyper[3],
    semu_quant[3],
    semu_comb[3]
]
semu_nodes = [
    semu_base[4],
    semu_fse[4],
    semu_rfecv[4],
    semu_hyper[4],
    semu_quant[4],
    semu_comb[4]
]

# %% [markdown]
# # Multi-Plots

# %% [markdown]
# ## Accuracy

# %%
fig, ax = plt.subplots(1,3)
fig.set_figwidth(18)

xlabels = ["Basis", "FS Emb.", "FS RFECV", "HPO", "Quant.", "Komb."]
ax[0].set_title("AGMP (skaliert)")
ax[0].set_ylim(0.7,1)
agmp_acc_container = ax[0].bar(xlabels, agmp_accs, color="#7395d3")
agmp_accs_rounded = [str(round(x, 4)).replace(".",",") for x in agmp_accs]
ax[0].bar_label(agmp_acc_container, agmp_accs_rounded, label_type="edge")
ax[0].set_ylabel("Balancierte Genauigkeit")
ax[0].axhline(agmp_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS (skaliert)")
ax[1].set_ylim(0.9,1.01)
harus_acc_container = ax[1].bar(xlabels, harus_accs, color="#dca682")
ax[1].bar_label(harus_acc_container, [str(round(x, 4)).replace(".",",") for x in harus_accs], label_type="edge")
ax[1].set_ylabel("Genauigkeit")
ax[1].axhline(harus_accs[0], color="black", linestyle=":")
ax[1].axhline(harus_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax[1].legend(loc="upper right")

ax[2].set_title("SeMu (skaliert)")
ax[2].set_ylim(0.7,1.04)
semu_accs_container = ax[2].bar(xlabels, semu_accs, color="#b1d09d")
ax[2].bar_label(semu_accs_container, [str(round(x, 4)).replace(".",",") for x in semu_accs], label_type="edge")
ax[2].set_ylabel("Genauigkeit")
ax[2].axhline(semu_accs[0], color="black", linestyle=":")
ax[2].axhline(semu_accs[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[2].legend(loc="upper right")



plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1,3)
fig.set_figwidth(18)

xlabels2 = ["FS Emb.", "FS RFECV", "HPO", "Quant.", "Komb."]
ax[0].set_title("AGMP (skaliert)")
ax[0].set_ylim(0.7,1)
agmp_acc_container = ax[0].bar(xlabels2, agmp_accs[1:6], color="#7395d3")
agmp_accs_rounded = [str(round(x, 4)).replace(".",",") for x in agmp_accs[1:6]]
ax[0].bar_label(agmp_acc_container, agmp_accs_rounded, label_type="edge")
ax[0].set_ylabel("Balancierte Genauigkeit")
ax[0].axhline(agmp_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS (skaliert)")
ax[1].set_ylim(0.9,1.01)
ax[1].axhline(harus_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
harus_acc_container = ax[1].bar(xlabels2, harus_accs[1:6], color="#dca682")
ax[1].bar_label(harus_acc_container, [str(round(x, 4)).replace(".",",") for x in harus_accs[1:6]], label_type="edge")
ax[1].set_ylabel("Genauigkeit")
ax[1].legend(loc="upper right")

ax[2].set_title("SeMu (skaliert)")
ax[2].set_ylim(0.7,1.04)
semu_accs_container = ax[2].bar(xlabels2, semu_accs[1:6], color="#b1d09d")
ax[2].bar_label(semu_accs_container, [str(round(x, 4)).replace(".",",") for x in semu_accs[1:6]], label_type="edge")
ax[2].set_ylabel("Genauigkeit")
ax[2].axhline(semu_accs[0], color="black", linestyle=":")
ax[2].axhline(semu_accs[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[2].legend(loc="upper right")



plt.tight_layout()
plt.show()

# %% [markdown]
# ## F-Scores

# %%
fig, ax = plt.subplots(1,3)
fig.set_figwidth(18)

ax[0].set_title("AGMP (skaliert)")
agmp_fscore_container = ax[0].bar(xlabels, agmp_fscores, color="#7395d3")
ax[0].bar_label(agmp_fscore_container, [str(round(x, 4)).replace(".",",") for x in agmp_fscores], label_type="edge")
ax[0].axhline(agmp_fscores[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylabel("F-Score")
ax[0].set_ylim(0,0.24)
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS (skaliert)")
ax[1].set_ylim(0.9,1.015)
harus_fscore_container = ax[1].bar(xlabels, harus_fscores, color="#dca682")
ax[1].bar_label(harus_fscore_container, [str(round(x, 4)).replace(".",",") for x in harus_fscores], label_type="edge")
ax[1].axhline(harus_fscores[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylabel("F-Score")
ax[1].legend(loc="upper right")

ax[2].set_title("SeMu (skaliert)")
ax[2].set_ylim(0.90,1.015)
semu_fscore_container = ax[2].bar(xlabels, semu_fscores, color="#b1d09d")
ax[2].bar_label(semu_fscore_container, [str(round(x, 4)).replace(".",",") for x in semu_fscores], label_type="edge")
ax[2].axhline(semu_fscores[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[2].set_ylabel("F-Score")
ax[2].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Speicherverbrauch

# %%
fig, ax = plt.subplots(1,3)
fig.set_figwidth(18)

ax[0].set_title("AGMP")
agmp_size_container = ax[0].bar(xlabels, agmp_sizes, color="#7395d3")
ax[0].bar_label(agmp_size_container, [str(x).replace(".",",") for x in agmp_sizes], label_type="edge")
ax[0].axhline(agmp_sizes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylabel("Speicherverbrauch in KB")
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS")
ax[1].set_ylim(0, 380)
harus_size_container = ax[1].bar(xlabels, harus_sizes, color="#dca682")
ax[1].bar_label(harus_size_container, [str(x).replace(".",",") for x in harus_sizes], label_type="edge")
ax[1].axhline(harus_sizes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylabel("Speicherverbrauch in KB")
ax[1].legend(loc="upper right")

ax[2].set_title("SeMu")
semu_size_container = ax[2].bar(xlabels, semu_sizes, color="#b1d09d")
ax[2].bar_label(semu_size_container, [str(x).replace(".",",") for x in semu_sizes], label_type="edge")
ax[2].axhline(semu_sizes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[2].set_ylabel("Speicherverbrauch in KB")
ax[2].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Anzahl der Knoten

# %%
fig, ax = plt.subplots(1,3)
fig.set_figwidth(18)

ax[0].set_title("AGMP")
ax[0].set_ylim(0, 4460)
agmp_nodes_container = ax[0].bar(xlabels, agmp_nodes, color="#7395d3")
ax[0].bar_label(agmp_nodes_container, [str(x).replace(".",",") for x in agmp_nodes], label_type="edge")
ax[0].axhline(agmp_nodes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylabel("Anzahl der Knoten")
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS")
ax[1].set_ylim(0, 17500)
harus_nodes_container = ax[1].bar(xlabels, harus_nodes, color="#dca682")
ax[1].bar_label(harus_nodes_container, [str(x).replace(".",",") for x in harus_nodes], label_type="edge")
ax[1].axhline(harus_nodes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylabel("Anzahl der Knoten")
ax[1].legend(loc="upper right")

ax[2].set_title("SeMu")
semu_nodes_container = ax[2].bar(xlabels, semu_nodes, color="#b1d09d")
ax[2].bar_label(semu_nodes_container, [str(x).replace(".",",") for x in semu_nodes], label_type="edge")
ax[2].axhline(semu_nodes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[2].set_ylabel("Anzahl der Knoten")
ax[2].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Inferenzgeschwindigkeit

# %%
fig, ax = plt.subplots(1,3)
fig.set_figwidth(18)

ax[0].set_title("AGMP")
agmp_speed_container = ax[0].bar(xlabels, agmp_speeds, color="#7395d3")
ax[0].bar_label(agmp_speed_container, [str(round(x, 2)).replace(".",",") for x in agmp_speeds], label_type="edge")
ax[0].axhline(agmp_speeds[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylim(0, 4450)
ax[0].legend(loc="upper right")
ax[0].set_ylabel("Inferenzgeschwindigkeit in ms")

ax[1].set_title("HARUS")
harus_speed_container = ax[1].bar(xlabels, harus_speeds, color="#dca682")
ax[1].bar_label(harus_speed_container, [str(round(x, 2)).replace(".",",") for x in harus_speeds], label_type="edge")
ax[1].axhline(harus_speeds[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylim(0, 7250)
ax[1].legend(loc="upper right")
ax[1].set_ylabel("Inferenzgeschwindigkeit in ms")

ax[2].set_title("SeMu")
semu_speed_container = ax[2].bar(xlabels, semu_speeds, color="#b1d09d")
ax[2].bar_label(semu_speed_container, [str(round(x, 2)).replace(".",",") for x in semu_speeds], label_type="edge")
ax[2].axhline(semu_speeds[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[2].legend(loc="upper right")
ax[2].set_ylabel("Inferenzgeschwindigkeit in ms")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Solo-Plots

# %% [markdown]
# ## Genauigkeit Totale Solo

# %%
fig, ax = plt.subplots()

bar_container = ax.bar(xlabels, agmp_accs, color="#7395d3")
ax.set_title("AGMP")
ax.bar_label(bar_container, [round(x, 4) for x in agmp_accs], label_type="edge")
ax.set_ylabel("Balancierte Genauigkeit")
ax.set_ylim(0,1.03)
ax.axhline(agmp_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("HARUS")
bar_container = ax.bar(xlabels, harus_accs, color="#dca682")
ax.bar_label(bar_container, [round(x, 4) for x in harus_accs], label_type="edge")
ax.set_ylabel("Genauigkeit")
ax.set_ylim(0,1.14)
ax.axhline(harus_accs[0], color="black", linestyle=":")
ax.axhline(harus_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("SeMu")
ax.set_ylim(0 , 1.14)
bar_container = ax.bar(xlabels, semu_accs, color="#b1d09d")
ax.bar_label(bar_container, [round(x, 4) for x in semu_accs], label_type="edge")
ax.set_ylabel("Genauigkeit")
ax.axhline(semu_accs[0], color="black", linestyle=":")
ax.axhline(semu_accs[0], color="black", linestyle=":", label="Wert des Basismodells")
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## F-Scores Totale Solo

# %%
fig, ax = plt.subplots()

bar_container = ax.bar(xlabels, agmp_fscores, color="#7395d3")
ax.set_title("AGMP")
ax.bar_label(bar_container, [round(x, 4) for x in agmp_fscores], label_type="edge")
ax.set_ylabel("F-Maß")
ax.set_ylim(0,1.03)
ax.axhline(agmp_fscores[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

bar_container = ax.bar(xlabels, harus_fscores, color="#dca682")
ax.set_title("HARUS")
ax.bar_label(bar_container, [round(x, 4) for x in harus_fscores], label_type="edge")
ax.set_ylabel("F-Maß")
ax.set_ylim(0,1.14)
ax.axhline(harus_fscores[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

bar_container = ax.bar(xlabels, semu_fscores, color="#b1d09d")
ax.set_title("SeMu")
ax.bar_label(bar_container, [round(x, 4) for x in semu_fscores], label_type="edge")
ax.set_ylabel("F-Maß")
ax.set_ylim(0,1.14)
ax.axhline(semu_fscores[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2 / 1 Plots

# %% [markdown]
# ## Accuracy

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12.6)

xlabels = ["Basis", "FS Emb.", "FS RFECV", "HPO", "Quant.", "Komb."]
ax[0].set_title("AGMP (skaliert)")
ax[0].set_ylim(0.7,1)
agmp_acc_container = ax[0].bar(xlabels, agmp_accs, color="#7395d3")
agmp_accs_rounded = [str(round(x, 4)).replace(".",",") for x in agmp_accs]
ax[0].bar_label(agmp_acc_container, agmp_accs_rounded, label_type="edge")
ax[0].set_ylabel("Balancierte Genauigkeit")
ax[0].axhline(agmp_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS (skaliert)")
ax[1].set_ylim(0.9,1.01)
harus_acc_container = ax[1].bar(xlabels, harus_accs, color="#dca682")
ax[1].bar_label(harus_acc_container, [str(round(x, 4)).replace(".",",") for x in harus_accs], label_type="edge")
ax[1].set_ylabel("Genauigkeit")
ax[1].axhline(harus_accs[0], color="black", linestyle=":")
ax[1].axhline(harus_accs[0], color="black", linestyle=":", label="Wert des Basismodells") 
ax[1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("SeMu (skaliert)")
ax.set_ylim(0.7,1.04)
semu_accs_container = ax.bar(xlabels, semu_accs, color="#b1d09d")
ax.bar_label(semu_accs_container, [str(round(x, 4)).replace(".",",") for x in semu_accs], label_type="edge")
ax.set_ylabel("Genauigkeit")
ax.axhline(semu_accs[0], color="black", linestyle=":")
ax.axhline(semu_accs[0], color="black", linestyle=":", label="Wert des Basismodells")
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## F-Maße

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12.6)

ax[0].set_title("AGMP (skaliert)")
agmp_fscore_container = ax[0].bar(xlabels, agmp_fscores, color="#7395d3")
ax[0].bar_label(agmp_fscore_container, [str(round(x, 4)).replace(".",",") for x in agmp_fscores], label_type="edge")
ax[0].axhline(agmp_fscores[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylabel("F-Maß")
ax[0].set_ylim(0,0.24)
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS (skaliert)")
ax[1].set_ylim(0.9,1.015)
harus_fscore_container = ax[1].bar(xlabels, harus_fscores, color="#dca682")
ax[1].bar_label(harus_fscore_container, [str(round(x, 4)).replace(".",",") for x in harus_fscores], label_type="edge")
ax[1].axhline(harus_fscores[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylabel("F-Maß")
ax[1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("SeMu (skaliert)")
ax.set_ylim(0.90,1.015)
semu_fscore_container = ax.bar(xlabels, semu_fscores, color="#b1d09d")
ax.bar_label(semu_fscore_container, [str(round(x, 4)).replace(".",",") for x in semu_fscores], label_type="edge")
ax.axhline(semu_fscores[0], color="black", linestyle=":", label="Wert des Basismodells")
ax.set_ylabel("F-Maß")
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Speicherverbrauch

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12.6)

ax[0].set_title("AGMP")
agmp_size_container = ax[0].bar(xlabels, agmp_sizes, color="#7395d3")
ax[0].bar_label(agmp_size_container, [str(x).replace(".",",") for x in agmp_sizes], label_type="edge")
ax[0].axhline(agmp_sizes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylabel("Speicherverbrauch in KB")
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS")
ax[1].set_ylim(0, 380)
harus_size_container = ax[1].bar(xlabels, harus_sizes, color="#dca682")
ax[1].bar_label(harus_size_container, [str(x).replace(".",",") for x in harus_sizes], label_type="edge")
ax[1].axhline(harus_sizes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylabel("Speicherverbrauch in KB")
ax[1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("SeMu")
semu_size_container = ax.bar(xlabels, semu_sizes, color="#b1d09d")
ax.bar_label(semu_size_container, [str(x).replace(".",",") for x in semu_sizes], label_type="edge")
ax.axhline(semu_sizes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax.set_ylabel("Speicherverbrauch in KB")
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Anzahl der Knoten

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12.6)

ax[0].set_title("AGMP")
ax[0].set_ylim(0, 4460)
agmp_nodes_container = ax[0].bar(xlabels, agmp_nodes, color="#7395d3")
ax[0].bar_label(agmp_nodes_container, [str(x).replace(".",",") for x in agmp_nodes], label_type="edge")
ax[0].axhline(agmp_nodes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylabel("Anzahl der Knoten")
ax[0].legend(loc="upper right")

ax[1].set_title("HARUS")
ax[1].set_ylim(0, 17500)
harus_nodes_container = ax[1].bar(xlabels, harus_nodes, color="#dca682")
ax[1].bar_label(harus_nodes_container, [str(x).replace(".",",") for x in harus_nodes], label_type="edge")
ax[1].axhline(harus_nodes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylabel("Anzahl der Knoten")
ax[1].legend(loc="upper right")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("SeMu")
semu_nodes_container = ax.bar(xlabels, semu_nodes, color="#b1d09d")
ax.bar_label(semu_nodes_container, [str(x).replace(".",",") for x in semu_nodes], label_type="edge")
ax.axhline(semu_nodes[0], color="black", linestyle=":", label="Wert des Basismodells")
ax.set_ylabel("Anzahl der Knoten")
ax.legend(loc="upper right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Inferenzgeschwindigkeit

# %%
fig, ax = plt.subplots(1,2)
fig.set_figwidth(12.6)

ax[0].set_title("AGMP")
agmp_speed_container = ax[0].bar(xlabels, agmp_speeds, color="#7395d3")
ax[0].bar_label(agmp_speed_container, [str(round(x, 2)).replace(".",",") for x in agmp_speeds], label_type="edge")
ax[0].axhline(agmp_speeds[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[0].set_ylim(0, 4450)
ax[0].legend(loc="upper right")
ax[0].set_ylabel("Inferenzgeschwindigkeit in ms")

ax[1].set_title("HARUS")
harus_speed_container = ax[1].bar(xlabels, harus_speeds, color="#dca682")
ax[1].bar_label(harus_speed_container, [str(round(x, 2)).replace(".",",") for x in harus_speeds], label_type="edge")
ax[1].axhline(harus_speeds[0], color="black", linestyle=":", label="Wert des Basismodells")
ax[1].set_ylim(0, 7250)
ax[1].legend(loc="upper right")
ax[1].set_ylabel("Inferenzgeschwindigkeit in ms")

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.set_title("SeMu")
semu_speed_container = ax.bar(xlabels, semu_speeds, color="#b1d09d")
ax.bar_label(semu_speed_container, [str(round(x, 2)).replace(".",",") for x in semu_speeds], label_type="edge")
ax.axhline(semu_speeds[0], color="black", linestyle=":", label="Wert des Basismodells")
ax.legend(loc="upper right")
ax.set_ylabel("Inferenzgeschwindigkeit in ms")

plt.tight_layout()
plt.show()
