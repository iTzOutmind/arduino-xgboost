# %% [markdown]
# # 1 Module importieren

# %%
import pandas as pd

import m2cgen as m2c

from scipy.stats import uniform

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from xgboost import XGBClassifier

# %% [markdown]
# # 2 Daten Importieren

# %% [markdown]
# ## 2.1 AGMP

# %%
agmp_dataPath = 'datasets/agmp/'
##### Data Import and Splitting #####
agmp_data = pd.read_csv(agmp_dataPath + 'gyro_mobile.csv')
agmp_data = agmp_data.drop(columns='timestamp')
agmp_xdata = agmp_data.iloc[:,:6]
agmp_ydata = agmp_data.iloc[:,6:]

agmp_xtrain, agmp_xvaltest, agmp_ytrain, agmp_yvaltest = train_test_split( 
    agmp_xdata,
    agmp_ydata,
    random_state=0,
    train_size=0.66,
    stratify=agmp_ydata
)

agmp_xval, agmp_xtest, agmp_yval, agmp_ytest = train_test_split( 
    agmp_xvaltest,
    agmp_yvaltest,
    random_state=0,
    train_size=0.5,
    stratify=agmp_yvaltest
)

# Zuvor gesicherte Datensätze nach RFECV werden importiert

agmp_xtrain = pd.read_csv("datasets/agmp/feature_selection/agmp_xtrain_rfecv.csv", sep=",")
agmp_xval = pd.read_csv("datasets/agmp/feature_selection/agmp_xval_rfecv.csv", sep=",")
agmp_xtest = pd.read_csv("datasets/agmp/feature_selection/agmp_xtest_rfecv.csv", sep=",")

classratio = len(agmp_data[agmp_data['Activity']==0]) / len(agmp_data[agmp_data['Activity']==1])

agmp_ev_val = [(agmp_xval,agmp_yval)]
agmp_ev_all = [(agmp_xtrain,agmp_ytrain),(agmp_xval,agmp_yval),(agmp_xtest,agmp_ytest)]

# %% [markdown]
# ## 2.2 HARUS

# %%
harus_dataPath = 'datasets/harus/'

harus_xdata = pd.read_csv(harus_dataPath + "xdata.csv", sep=";")                     
harus_ydata = pd.read_csv(harus_dataPath + "ydata.csv", sep=";")

harus_xtrain, harus_xvaltest, harus_ytrain, harus_yvaltest = train_test_split( 
    harus_xdata,
    harus_ydata,
    random_state=0,
    train_size=0.66,
    stratify=harus_ydata
)

harus_xval, harus_xtest, harus_yval, harus_ytest = train_test_split( 
    harus_xvaltest,
    harus_yvaltest,
    random_state=0,
    train_size=0.5,
    stratify=harus_yvaltest
)

# Zuvor gesicherte Datensätze nach RFECV werden importiert

harus_xtrain = pd.read_csv("datasets/harus/feature_selection/harus_xtrain_rfecv.csv", sep=",")
harus_xval = pd.read_csv("datasets/harus/feature_selection/harus_xval_rfecv.csv", sep=",")
harus_xtest = pd.read_csv("datasets/harus/feature_selection/harus_xtest_rfecv.csv", sep=",")

harus_ev_val = [(harus_xval,harus_yval)]
harus_ev_all = [(harus_xtrain,harus_ytrain),(harus_xval,harus_yval),(harus_xtest,harus_ytest)]

# %% [markdown]
# ## 2.3 SeMu

# %%
semu_dataPath = 'datasets/semu/'                         # Set location of dataset

semu_data = pd.read_csv(semu_dataPath + 'secondary_mushroom.csv', sep=";")    # Dataset is imbalanced with only ~1.7% of all labels being 0's
semu_xdata = semu_data.iloc[:,:20]
semu_ydata = semu_data.iloc[:,20:]    # Classratio 9:11

def encodeLabels():
    encoders = {}

    # Create a list with the names of all columns, that contain categorical data
    xdata_cats = list(semu_xdata.columns)
    [xdata_cats.remove(i) for i in ['cap-diameter','stem-height','stem-width']]

    # Encode all categorical feature-labels and save encoders in a dictionary
    for cat in xdata_cats:
        le = LabelEncoder()
        semu_xdata[cat] = le.fit_transform(semu_xdata[cat])
        encoders.update({cat:le})

    le = LabelEncoder()
    semu_ydata['class'] = le.fit_transform(semu_ydata['class'])
    encoders.update({'class':le})

    return encoders

def encodeOHE():
    xdata_categorical = semu_xdata.copy()
    numeric_features = ['cap-diameter','stem-height','stem-width']

    for i in numeric_features:
        xdata_categorical = xdata_categorical.drop(i,axis=1) 

    xdata_numeric = pd.DataFrame()
    for feat in numeric_features:
        xdata_numeric[feat] = semu_xdata[feat]

    ohe = OneHotEncoder()
    ohedata = ohe.fit_transform(xdata_categorical)

    xdata_categorical_ohe = pd.DataFrame(ohedata.toarray(), columns=ohe.get_feature_names_out(), dtype=int)

    xdata_encoded = pd.concat([xdata_numeric, xdata_categorical_ohe],axis=1)

    yEncoder = LabelEncoder()
    semu_ydata['class'] = yEncoder.fit_transform(semu_ydata['class'])

    return xdata_encoded, yEncoder

semu_xdata, yEncoder = encodeOHE() # Weil keine Rangfolge zwischen den einzelnen Kategorien herrscht, wird OHE angewendet

semu_xtrain, semu_xvaltest, semu_ytrain, semu_yvaltest = train_test_split( 
    semu_xdata,
    semu_ydata,
    random_state=0,
    train_size=0.66,
    stratify=semu_ydata
)

semu_xval, semu_xtest, semu_yval, semu_ytest = train_test_split( 
    semu_xvaltest,
    semu_yvaltest,
    random_state=0,
    train_size=0.5,
    stratify=semu_yvaltest
)

# Zuvor gesicherte Datensätze nach RFECV werden importiert

semu_xtrain = pd.read_csv("datasets/semu/feature_selection/semu_xtrain_rfecv.csv", sep=",")
semu_xval = pd.read_csv("datasets/semu/feature_selection/semu_xval_rfecv.csv", sep=",")
semu_xtest = pd.read_csv("datasets/semu/feature_selection/semu_xtest_rfecv.csv", sep=",")

semu_ev_val = [(semu_xval,semu_yval)]
semu_ev_all = [(semu_xtrain,semu_ytrain),(semu_xval,semu_yval),(semu_xtest,semu_ytest)]

# %% [markdown]
# # 3 Suchraum definieren

# %%
searchspace = {
    'max_depth': [1,3,5,7,9],
    'n_estimators': [100,200,300,400,500,600,700,800,900,1000],
    'min_child_weight': [1,3,5,7],
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'learning_rate': uniform(0.01, 0.29),
    'gamma': uniform(0.1, 0.8)
}

# %% [markdown]
# # 4 Hyperparameter optimieren mit Random Search

# %% [markdown]
# ## 4.1 AGMP

# %%
agmp_xgb = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    scale_pos_weight=classratio,
    n_jobs=-1,
    early_stopping_rounds=10,
)

agmp_random_search = RandomizedSearchCV(
    estimator=agmp_xgb, 
    param_distributions=searchspace, 
    scoring='balanced_accuracy',
    n_iter=250, 
    cv=5,
    n_jobs=-1, 
    verbose=1, 
    random_state=0
)
agmp_random_search.fit(
    agmp_xtrain, agmp_ytrain,
    eval_set=agmp_ev_val,
    verbose=True
)

# Print best parameters
print(f"Best parameters: {agmp_random_search.best_params_}")
print(f"Best score: {agmp_random_search.best_score_}")
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# [0]	validation_0-logloss:0.64407[0]	validation_0-logloss:0.63620
# [0]	validation_0-logloss:0.63708
# [0]	validation_0-logloss:0.63581
# [0]	validation_0-logloss:0.68315
# [0]	validation_0-logloss:0.68421
# [0]	validation_0-logloss:0.63134
#
# [1]	validation_0-logloss:0.58785[1]	validation_0-logloss:0.59170
#
# [1]	validation_0-logloss:0.58713
# [1]	validation_0-logloss:0.58654[1]	validation_0-logloss:0.58719
# [1]	validation_0-logloss:0.67498
#
# [1]	validation_0-logloss:0.67590
# [2]	validation_0-logloss:0.55360
# [2]	validation_0-logloss:0.55553
# [2]	validation_0-logloss:0.55813
# [0]	validation_0-logloss:0.68324
# [2]	validation_0-logloss:0.55592
# [2]	validation_0-logloss:0.55179
# [2]	validation_0-logloss:0.66673
# [2]	validation_0-logloss:0.66630
# [3]	validation_0-logloss:0.53463
# [3]	validation_0-logloss:0.53562
# [1]	validation_0-logloss:0.67502
# [3]	validation_0-logloss:0.53061
# [3]	validation_0-logloss:0.52145
# [0]	validation_0-logloss:0.61775
# [3]	validation_0-logloss:0.65802
# [3]	validation_0-logloss:0.52758
# [3]	validation_0-logloss:0.65814
# [4]	validation_0-logloss:0.51606
# [4]	validation_0-logloss:0.51554
# [1]	validation_0-logloss:0.55566
# [2]	validation_0-logloss:0.66637[4]	validation_0-logloss:0.51243
#
# [4]	validation_0-logloss:0.50106
# [2]	validation_0-logloss:0.52624
# [4]	validation_0-logloss:0.64965
# [4]	validation_0-logloss:0.65012
# [4]	validation_0-logloss:0.50865
# [5]	validation_0-logloss:0.49062
# [3]	validation_0-logloss:0.50951
# [5]	validation_0-logloss:0.48933
# [4]	validation_0-logloss:0.49663
# [5]	validation_0-logloss:0.48783
# [0]	validation_0-logloss:0.60549
# [5]	validation_0-logloss:0.47311
# [5]	validation_0-logloss:0.48774
# [5]	validation_0-logloss:0.64311
# [1]	validation_0-logloss:0.55613[6]	validation_0-logloss:0.48001
# [5]	validation_0-logloss:0.64241
#
# [6]	validation_0-logloss:0.46577
# [3]	validation_0-logloss:0.65855
# [5]	validation_0-logloss:0.48358
# [6]	validation_0-logloss:0.47773
# [0]	validation_0-logloss:0.68450
# [2]	validation_0-logloss:0.52877
# [7]	validation_0-logloss:0.45862[6]	validation_0-logloss:0.47515
#
# [6]	validation_0-logloss:0.46406
# [6]	validation_0-logloss:0.63574
# [3]	validation_0-logloss:0.50856
# [8]	validation_0-logloss:0.44934
# [7]	validation_0-logloss:0.47378
# [6]	validation_0-logloss:0.63477
# [7]	validation_0-logloss:0.47131[4]	validation_0-logloss:0.65060
#
# [4]	validation_0-logloss:0.49918
# [6]	validation_0-logloss:0.47202
# [7]	validation_0-logloss:0.46677
# [7]	validation_0-logloss:0.44794
# [1]	validation_0-logloss:0.67691
# [9]	validation_0-logloss:0.43292
# [5]	validation_0-logloss:0.47338
# [7]	validation_0-logloss:0.62872
# [8]	validation_0-logloss:0.46620
# [6]	validation_0-logloss:0.46775
# [8]	validation_0-logloss:0.46478
# [10]	validation_0-logloss:0.43917
# [5]	validation_0-logloss:0.64341
# [7]	validation_0-logloss:0.62758
# [0]	validation_0-logloss:0.68568
# [8]	validation_0-logloss:0.45901[8]	validation_0-logloss:0.43650
#
# [7]	validation_0-logloss:0.46363
# [7]	validation_0-logloss:0.46664
# [11]	validation_0-logloss:0.42981
# [2]	validation_0-logloss:0.66798
# [8]	validation_0-logloss:0.62216
# [8]	validation_0-logloss:0.45547
# [12]	validation_0-logloss:0.42273[9]	validation_0-logloss:0.44576
#
# [9]	validation_0-logloss:0.44045
# [9]	validation_0-logloss:0.42808
# [8]	validation_0-logloss:0.62050
# [0]	validation_0-logloss:0.61887
# [1]	validation_0-logloss:0.67605
# [9]	validation_0-logloss:0.43160
# [13]	validation_0-logloss:0.41511
# [6]	validation_0-logloss:0.63618
# [8]	validation_0-logloss:0.45400[9]	validation_0-logloss:0.44434
#
# [1]	validation_0-logloss:0.56608
# [10]	validation_0-logloss:0.43116
# [3]	validation_0-logloss:0.65976
# [14]	validation_0-logloss:0.41444[9]	validation_0-logloss:0.61567
#
# [10]	validation_0-logloss:0.43675[10]	validation_0-logloss:0.42181
#
# [2]	validation_0-logloss:0.53996
# [11]	validation_0-logloss:0.42307
# [10]	validation_0-logloss:0.43997
# [15]	validation_0-logloss:0.40978
# [2]	validation_0-logloss:0.66805
# [9]	validation_0-logloss:0.61394
# [12]	validation_0-logloss:0.41805[10]	validation_0-logloss:0.44088
#
# [7]	validation_0-logloss:0.62948
# [9]	validation_0-logloss:0.43527[16]	validation_0-logloss:0.40888
#
# [11]	validation_0-logloss:0.41205
# [3]	validation_0-logloss:0.51962
# [4]	validation_0-logloss:0.65154
# [10]	validation_0-logloss:0.60936
# [13]	validation_0-logloss:0.41807
# [11]	validation_0-logloss:0.42506
# [0]	validation_0-logloss:0.63181[0]	validation_0-logloss:0.62155
#
# [11]	validation_0-logloss:0.42670
# [4]	validation_0-logloss:0.50085
# [14]	validation_0-logloss:0.41695
# [11]	validation_0-logloss:0.42763[3]	validation_0-logloss:0.65940
#
# [0]	validation_0-logloss:0.61401
# [1]	validation_0-logloss:0.56003
# [1]	validation_0-logloss:0.56353
# [10]	validation_0-logloss:0.60737
# [12]	validation_0-logloss:0.40794
# [5]	validation_0-logloss:0.48193
# [17]	validation_0-logloss:0.39414
# [15]	validation_0-logloss:0.41166
# [5]	validation_0-logloss:0.64451[2]	validation_0-logloss:0.53248
# [8]	validation_0-logloss:0.62311
# [2]	validation_0-logloss:0.53819
#
# [10]	validation_0-logloss:0.43105[11]	validation_0-logloss:0.60322
#
# [12]	validation_0-logloss:0.42228
# [6]	validation_0-logloss:0.47265
# [12]	validation_0-logloss:0.42269
# [16]	validation_0-logloss:0.40553
# [3]	validation_0-logloss:0.51454[1]	validation_0-logloss:0.55560
#
# [3]	validation_0-logloss:0.50813
# [12]	validation_0-logloss:0.42598
# [18]	validation_0-logloss:0.39156
# [4]	validation_0-logloss:0.65178
# [0]	validation_0-logloss:0.61458
# [7]	validation_0-logloss:0.47200[13]	validation_0-logloss:0.40366
#
# [4]	validation_0-logloss:0.49711[4]	validation_0-logloss:0.49298
#
# [9]	validation_0-logloss:0.61634
# [11]	validation_0-logloss:0.60129
# [19]	validation_0-logloss:0.39098[8]	validation_0-logloss:0.46078
# [6]	validation_0-logloss:0.63721
#
# [13]	validation_0-logloss:0.41708
# [12]	validation_0-logloss:0.59719
# [5]	validation_0-logloss:0.47657[5]	validation_0-logloss:0.47970
# [2]	validation_0-logloss:0.51909
#
# [14]	validation_0-logloss:0.40012[13]	validation_0-logloss:0.41918
#
# [1]	validation_0-logloss:0.55533
# [9]	validation_0-logloss:0.44164
# [20]	validation_0-logloss:0.38594
# [0]	validation_0-logloss:0.61337
# [17]	validation_0-logloss:0.40514[13]	validation_0-logloss:0.42087
#
# [6]	validation_0-logloss:0.46518[6]	validation_0-logloss:0.45437
#
# [10]	validation_0-logloss:0.44044
# [10]	validation_0-logloss:0.61041[5]	validation_0-logloss:0.64495
#
# [21]	validation_0-logloss:0.38913
# [18]	validation_0-logloss:0.39549
# [14]	validation_0-logloss:0.41582
# [7]	validation_0-logloss:0.63033
# [12]	validation_0-logloss:0.59482
# [7]	validation_0-logloss:0.44411
# [7]	validation_0-logloss:0.46251
# [0]	validation_0-logloss:0.62521
# [15]	validation_0-logloss:0.39320
# [13]	validation_0-logloss:0.59140
# [3]	validation_0-logloss:0.49740
# [11]	validation_0-logloss:0.42719
# [22]	validation_0-logloss:0.38506
# [19]	validation_0-logloss:0.38974
# [2]	validation_0-logloss:0.51757
# [1]	validation_0-logloss:0.55272
# [14]	validation_0-logloss:0.42050
# [14]	validation_0-logloss:0.41886
# [8]	validation_0-logloss:0.45523[8]	validation_0-logloss:0.43291
#
# [12]	validation_0-logloss:0.42247
# [23]	validation_0-logloss:0.38684
# [15]	validation_0-logloss:0.40585
# [20]	validation_0-logloss:0.38582
# [9]	validation_0-logloss:0.43217[9]	validation_0-logloss:0.42823
#
# [16]	validation_0-logloss:0.39101
# [11]	validation_0-logloss:0.60396
# [1]	validation_0-logloss:0.55267
# [8]	validation_0-logloss:0.62366
# [24]	validation_0-logloss:0.38329
# [4]	validation_0-logloss:0.48432
# [21]	validation_0-logloss:0.38381
# [13]	validation_0-logloss:0.41865
# [15]	validation_0-logloss:0.41103
# [13]	validation_0-logloss:0.58892
# [14]	validation_0-logloss:0.58601
# [2]	validation_0-logloss:0.51320
# [15]	validation_0-logloss:0.41015
# [0]	validation_0-logloss:0.61794
# [3]	validation_0-logloss:0.49692
# [10]	validation_0-logloss:0.43119
# [10]	validation_0-logloss:0.43672
# [25]	validation_0-logloss:0.38283
# [14]	validation_0-logloss:0.41640
# [16]	validation_0-logloss:0.40495
# [6]	validation_0-logloss:0.63712
# [11]	validation_0-logloss:0.42769
# [22]	validation_0-logloss:0.38587
# [17]	validation_0-logloss:0.38876
# [2]	validation_0-logloss:0.51943
# [26]	validation_0-logloss:0.38375
# [15]	validation_0-logloss:0.41547
# [12]	validation_0-logloss:0.59835
# [5]	validation_0-logloss:0.45712
# [3]	validation_0-logloss:0.48898
# [15]	validation_0-logloss:0.58072
# [1]	validation_0-logloss:0.55672
# [14]	validation_0-logloss:0.58356
# [12]	validation_0-logloss:0.42369
# [0]	validation_0-logloss:0.62448
# [9]	validation_0-logloss:0.61699
# [4]	validation_0-logloss:0.48335
# [27]	validation_0-logloss:0.38687
# [23]	validation_0-logloss:0.38451
# [16]	validation_0-logloss:0.41128
# [16]	validation_0-logloss:0.41034
# [11]	validation_0-logloss:0.42502
# [17]	validation_0-logloss:0.39561
# [13]	validation_0-logloss:0.41818
# [28]	validation_0-logloss:0.38074
# [16]	validation_0-logloss:0.40833
# [7]	validation_0-logloss:0.62938
# [18]	validation_0-logloss:0.38736
# [17]	validation_0-logloss:0.40879
# [3]	validation_0-logloss:0.48182
# [6]	validation_0-logloss:0.44875
# [12]	validation_0-logloss:0.42663
# [24]	validation_0-logloss:0.37787
# [14]	validation_0-logloss:0.41919
# [13]	validation_0-logloss:0.59276
# [4]	validation_0-logloss:0.47557
# [29]	validation_0-logloss:0.38383
# [5]	validation_0-logloss:0.45393
# [1]	validation_0-logloss:0.57322
# [18]	validation_0-logloss:0.40075
# [16]	validation_0-logloss:0.57585
# [10]	validation_0-logloss:0.61076
# [18]	validation_0-logloss:0.39012
# [15]	validation_0-logloss:0.41702
# [30]	validation_0-logloss:0.38200
# [19]	validation_0-logloss:0.39465
# [17]	validation_0-logloss:0.40240
# [19]	validation_0-logloss:0.38355
# [4]	validation_0-logloss:0.46069
# [8]	validation_0-logloss:0.62202
# [11]	validation_0-logloss:0.41776
# [7]	validation_0-logloss:0.44460
# [16]	validation_0-logloss:0.41763
# [31]	validation_0-logloss:0.38510
# [6]	validation_0-logloss:0.44620
# [5]	validation_0-logloss:0.44282
# [20]	validation_0-logloss:0.39064
# [0]	validation_0-logloss:0.62669
# [15]	validation_0-logloss:0.57798
# [13]	validation_0-logloss:0.42060
# [17]	validation_0-logloss:0.40957
# [25]	validation_0-logloss:0.37789
# [2]	validation_0-logloss:0.53519
# [19]	validation_0-logloss:0.38676
# [32]	validation_0-logloss:0.38166
# [2]	validation_0-logloss:0.52025
# [17]	validation_0-logloss:0.40004
# [17]	validation_0-logloss:0.57073
# [11]	validation_0-logloss:0.60470
# [21]	validation_0-logloss:0.39172
# [18]	validation_0-logloss:0.39598
# [14]	validation_0-logloss:0.41371
# [18]	validation_0-logloss:0.40317
# [12]	validation_0-logloss:0.41339
# [26]	validation_0-logloss:0.37511
# [33]	validation_0-logloss:0.38086
# [8]	validation_0-logloss:0.44037
# [14]	validation_0-logloss:0.58790
# [9]	validation_0-logloss:0.61595
# [6]	validation_0-logloss:0.43484
# [7]	validation_0-logloss:0.44106
# [22]	validation_0-logloss:0.38993
# [27]	validation_0-logloss:0.37532
# [1]	validation_0-logloss:0.57847
# [34]	validation_0-logloss:0.37807
# [19]	validation_0-logloss:0.40126
# [18]	validation_0-logloss:0.39460
# [3]	validation_0-logloss:0.51115
# [20]	validation_0-logloss:0.37954
# [20]	validation_0-logloss:0.38446
# [15]	validation_0-logloss:0.40494
# [16]	validation_0-logloss:0.57257
# [23]	validation_0-logloss:0.39487
# [12]	validation_0-logloss:0.59874
# [5]	validation_0-logloss:0.45140
# [28]	validation_0-logloss:0.36822
# [19]	validation_0-logloss:0.39251
# [9]	validation_0-logloss:0.41832
# [20]	validation_0-logloss:0.39527
# [3]	validation_0-logloss:0.49948
# [13]	validation_0-logloss:0.41079[18]	validation_0-logloss:0.56573
# [24]	validation_0-logloss:0.38453
# [8]	validation_0-logloss:0.43559
# [29]	validation_0-logloss:0.36857
# [7]	validation_0-logloss:0.43017
# [4]	validation_0-logloss:0.49479[16]	validation_0-logloss:0.40286
#
# [2]	validation_0-logloss:0.54115
# [10]	validation_0-logloss:0.60995
# [35]	validation_0-logloss:0.37218
# [21]	validation_0-logloss:0.40031
# [21]	validation_0-logloss:0.38422
# [25]	validation_0-logloss:0.38325
# [6]	validation_0-logloss:0.42919
# [21]	validation_0-logloss:0.37945
# [30]	validation_0-logloss:0.36920
# [17]	validation_0-logloss:0.40236
# [20]	validation_0-logloss:0.38964
# [36]	validation_0-logloss:0.36954
# [10]	validation_0-logloss:0.41595
# [17]	validation_0-logloss:0.56730
# [22]	validation_0-logloss:0.39620
# [13]	validation_0-logloss:0.59282
# [15]	validation_0-logloss:0.58238
# [4]	validation_0-logloss:0.48411
# [26]	validation_0-logloss:0.38047
# [19]	validation_0-logloss:0.39109[5]	validation_0-logloss:0.46528
# [3]	validation_0-logloss:0.51813
#
# [18]	validation_0-logloss:0.40304
# [8]	validation_0-logloss:0.42578
# [9]	validation_0-logloss:0.41529
# [19]	validation_0-logloss:0.56107
# [37]	validation_0-logloss:0.37347
# [22]	validation_0-logloss:0.38107
# [23]	validation_0-logloss:0.39801
# [11]	validation_0-logloss:0.60315
# [7]	validation_0-logloss:0.41319
# [19]	validation_0-logloss:0.40153
# [31]	validation_0-logloss:0.36921
# [27]	validation_0-logloss:0.38261
# [22]	validation_0-logloss:0.37808
# [11]	validation_0-logloss:0.40357
# [38]	validation_0-logloss:0.37766
# [24]	validation_0-logloss:0.38870
# [5]	validation_0-logloss:0.45571
# [6]	validation_0-logloss:0.45438
# [20]	validation_0-logloss:0.39335[16]	validation_0-logloss:0.57766
# [9]	validation_0-logloss:0.40502
#
# [32]	validation_0-logloss:0.36633[28]	validation_0-logloss:0.37704
#
# [10]	validation_0-logloss:0.41318
# [4]	validation_0-logloss:0.50174
# [18]	validation_0-logloss:0.56236[20]	validation_0-logloss:0.38838
#
#
# [23]	validation_0-logloss:0.37858
# [39]	validation_0-logloss:0.37685
# [25]	validation_0-logloss:0.38422
# [20]	validation_0-logloss:0.55676
# [8]	validation_0-logloss:0.40478[21]	validation_0-logloss:0.39003
#
# [12]	validation_0-logloss:0.59725
# [23]	validation_0-logloss:0.37618
# [29]	validation_0-logloss:0.37840[21]	validation_0-logloss:0.39419
# [33]	validation_0-logloss:0.36674
#
# [12]	validation_0-logloss:0.40049
# [14]	validation_0-logloss:0.58772
# [40]	validation_0-logloss:0.37381
# [26]	validation_0-logloss:0.38536
# [6]	validation_0-logloss:0.44798
# [5]	validation_0-logloss:0.47480
# [34]	validation_0-logloss:0.36664
# [30]	validation_0-logloss:0.37928[22]	validation_0-logloss:0.38727
#
# [10]	validation_0-logloss:0.40245
# [11]	validation_0-logloss:0.40133
# [41]	validation_0-logloss:0.37710
# [27]	validation_0-logloss:0.38621[17]	validation_0-logloss:0.57219
#
# [24]	validation_0-logloss:0.37739
# [21]	validation_0-logloss:0.38876
# [14]	validation_0-logloss:0.40947[9]	validation_0-logloss:0.39958
# [22]	validation_0-logloss:0.38724
#
# [35]	validation_0-logloss:0.36744
# [24]	validation_0-logloss:0.37457
# [31]	validation_0-logloss:0.37977
# [19]	validation_0-logloss:0.55774
# [13]	validation_0-logloss:0.39726
# [23]	validation_0-logloss:0.39026
# [42]	validation_0-logloss:0.38043
# [13]	validation_0-logloss:0.59199
# [28]	validation_0-logloss:0.37890
# [6]	validation_0-logloss:0.46437[7]	validation_0-logloss:0.44610
#
# [15]	validation_0-logloss:0.58243
# [36]	validation_0-logloss:0.36524
# [21]	validation_0-logloss:0.55230
# [32]	validation_0-logloss:0.37835
# [11]	validation_0-logloss:0.39029
# [12]	validation_0-logloss:0.39856
# [7]	validation_0-logloss:0.44429
# [24]	validation_0-logloss:0.38539
# [43]	validation_0-logloss:0.38056
# [29]	validation_0-logloss:0.38128
# [22]	validation_0-logloss:0.38596
# [10]	validation_0-logloss:0.39352[18]	validation_0-logloss:0.56698
#
# [37]	validation_0-logloss:0.36216
# [25]	validation_0-logloss:0.37155
# [23]	validation_0-logloss:0.38564
# [25]	validation_0-logloss:0.37586[33]	validation_0-logloss:0.37692
#
# [8]	validation_0-logloss:0.44108
# [44]	validation_0-logloss:0.38122
# [30]	validation_0-logloss:0.38017
# [14]	validation_0-logloss:0.39753
# [20]	validation_0-logloss:0.55308
# [38]	validation_0-logloss:0.36686
# [12]	validation_0-logloss:0.38694
# [34]	validation_0-logloss:0.37582
# [14]	validation_0-logloss:0.58695
# [25]	validation_0-logloss:0.38180
# [13]	validation_0-logloss:0.39519
# [16]	validation_0-logloss:0.57748
# [15]	validation_0-logloss:0.40022
# [8]	validation_0-logloss:0.44089
# [45]	validation_0-logloss:0.38045[22]	validation_0-logloss:0.54810
#
# [31]	validation_0-logloss:0.38511
# [0]	validation_0-logloss:0.62789
# [23]	validation_0-logloss:0.38448
# [11]	validation_0-logloss:0.38588
# [26]	validation_0-logloss:0.37434
# [26]	validation_0-logloss:0.36787
# [39]	validation_0-logloss:0.36969[35]	validation_0-logloss:0.37373
# [9]	validation_0-logloss:0.42091
#
# [26]	validation_0-logloss:0.37420
# [19]	validation_0-logloss:0.56220
# [32]	validation_0-logloss:0.38056
# [15]	validation_0-logloss:0.39105
# [24]	validation_0-logloss:0.38174
# [13]	validation_0-logloss:0.38419
# [27]	validation_0-logloss:0.37115
# [21]	validation_0-logloss:0.54843
# [7]	validation_0-logloss:0.45761
# [15]	validation_0-logloss:0.58093
# [9]	validation_0-logloss:0.41839
# [33]	validation_0-logloss:0.37793
# [36]	validation_0-logloss:0.37013[10]	validation_0-logloss:0.41642
#
# [24]	validation_0-logloss:0.38128
# [12]	validation_0-logloss:0.38553[27]	validation_0-logloss:0.37315
# [14]	validation_0-logloss:0.39464
#
# [27]	validation_0-logloss:0.36563
# [1]	validation_0-logloss:0.57529
# [28]	validation_0-logloss:0.37550
# [23]	validation_0-logloss:0.54364
# [17]	validation_0-logloss:0.57232
# [40]	validation_0-logloss:0.37187
# [34]	validation_0-logloss:0.37713
# [16]	validation_0-logloss:0.38970[37]	validation_0-logloss:0.36728
#
# [14]	validation_0-logloss:0.38403[20]	validation_0-logloss:0.55765
#
# [16]	validation_0-logloss:0.39738[8]	validation_0-logloss:0.45347
#
# [25]	validation_0-logloss:0.37917
# [29]	validation_0-logloss:0.37288
# [11]	validation_0-logloss:0.40286[41]	validation_0-logloss:0.37333
#
# [35]	validation_0-logloss:0.37178
# [38]	validation_0-logloss:0.37174
# [2]	validation_0-logloss:0.53970
# [25]	validation_0-logloss:0.37905[15]	validation_0-logloss:0.38731
# [16]	validation_0-logloss:0.57532
#
# [13]	validation_0-logloss:0.38268[22]	validation_0-logloss:0.54422
#
# [28]	validation_0-logloss:0.36989
# [30]	validation_0-logloss:0.37454
# [42]	validation_0-logloss:0.37489
# [36]	validation_0-logloss:0.36875
# [10]	validation_0-logloss:0.41730
# [39]	validation_0-logloss:0.36958
# [17]	validation_0-logloss:0.38566
# [9]	validation_0-logloss:0.43387
# [24]	validation_0-logloss:0.53932
# [17]	validation_0-logloss:0.39092[15]	validation_0-logloss:0.37750
# [18]	validation_0-logloss:0.56729
#
# [28]	validation_0-logloss:0.36514[12]	validation_0-logloss:0.39781
#
# [43]	validation_0-logloss:0.36987[26]	validation_0-logloss:0.37804
# [21]	validation_0-logloss:0.55318
# [31]	validation_0-logloss:0.37760
#
# [37]	validation_0-logloss:0.36920[3]	validation_0-logloss:0.51832
#
# [26]	validation_0-logloss:0.37734
# [40]	validation_0-logloss:0.37444
# [16]	validation_0-logloss:0.38689
# [29]	validation_0-logloss:0.36805
# [14]	validation_0-logloss:0.37911
# [32]	validation_0-logloss:0.38038[44]	validation_0-logloss:0.37068
# [23]	validation_0-logloss:0.54021
#
# [10]	validation_0-logloss:0.42984
# [38]	validation_0-logloss:0.37345
# [18]	validation_0-logloss:0.38255
# [41]	validation_0-logloss:0.37687
# [11]	validation_0-logloss:0.40407
# [17]	validation_0-logloss:0.56982
# [18]	validation_0-logloss:0.38625
# [16]	validation_0-logloss:0.37503
# [13]	validation_0-logloss:0.39541
# [45]	validation_0-logloss:0.36878
# [4]	validation_0-logloss:0.50307
# [27]	validation_0-logloss:0.37628
# [29]	validation_0-logloss:0.36381
# [33]	validation_0-logloss:0.37431
# [39]	validation_0-logloss:0.37513
# [42]	validation_0-logloss:0.37541
# [19]	validation_0-logloss:0.56269
# [30]	validation_0-logloss:0.36820
# [25]	validation_0-logloss:0.53507
# [17]	validation_0-logloss:0.38173
# [22]	validation_0-logloss:0.54901
# [27]	validation_0-logloss:0.37598
# [11]	validation_0-logloss:0.41598
# [46]	validation_0-logloss:0.36672
# [15]	validation_0-logloss:0.37547
# [40]	validation_0-logloss:0.37636
# [43]	validation_0-logloss:0.37430
# [14]	validation_0-logloss:0.39406
# [12]	validation_0-logloss:0.40233
# [24]	validation_0-logloss:0.53557
# [19]	validation_0-logloss:0.38080
# [19]	validation_0-logloss:0.38323
# [17]	validation_0-logloss:0.37226
# [5]	validation_0-logloss:0.47389
# [30]	validation_0-logloss:0.36249
# [28]	validation_0-logloss:0.37300
# [34]	validation_0-logloss:0.37358
# [41]	validation_0-logloss:0.37874
# [18]	validation_0-logloss:0.56464
# [44]	validation_0-logloss:0.37530
# [18]	validation_0-logloss:0.37781
# [31]	validation_0-logloss:0.36721
# [28]	validation_0-logloss:0.37290
# [16]	validation_0-logloss:0.37384
# [35]	validation_0-logloss:0.37688
# [20]	validation_0-logloss:0.55843
# [42]	validation_0-logloss:0.37857
# [26]	validation_0-logloss:0.53117
# [23]	validation_0-logloss:0.54498
# [45]	validation_0-logloss:0.37257
# [13]	validation_0-logloss:0.39840
# [20]	validation_0-logloss:0.37909
# [18]	validation_0-logloss:0.37077
# [15]	validation_0-logloss:0.38504
# [6]	validation_0-logloss:0.46455
# [20]	validation_0-logloss:0.37904
# [36]	validation_0-logloss:0.37742
# [29]	validation_0-logloss:0.37056
# [43]	validation_0-logloss:0.38151
# [31]	validation_0-logloss:0.36399
# [0]	validation_0-logloss:0.62555
# [46]	validation_0-logloss:0.36989
# [32]	validation_0-logloss:0.36643
# [19]	validation_0-logloss:0.37702
# [29]	validation_0-logloss:0.37062
# [25]	validation_0-logloss:0.53126
# [19]	validation_0-logloss:0.55993
# [12]	validation_0-logloss:0.41084
# [44]	validation_0-logloss:0.38323
# [17]	validation_0-logloss:0.37244
# [19]	validation_0-logloss:0.36969
# [7]	validation_0-logloss:0.45859
# [21]	validation_0-logloss:0.37850
# [16]	validation_0-logloss:0.38418
# [14]	validation_0-logloss:0.39877
# [24]	validation_0-logloss:0.54069
# [27]	validation_0-logloss:0.52777
# [21]	validation_0-logloss:0.55394
# [30]	validation_0-logloss:0.37174
# [45]	validation_0-logloss:0.38027
# [21]	validation_0-logloss:0.37831
# [33]	validation_0-logloss:0.36629
# [20]	validation_0-logloss:0.37632
# [30]	validation_0-logloss:0.37227
# [1]	validation_0-logloss:0.57506
# [13]	validation_0-logloss:0.40876
# [18]	validation_0-logloss:0.37080
# [8]	validation_0-logloss:0.45403
# [20]	validation_0-logloss:0.36761
# [17]	validation_0-logloss:0.37888
# [26]	validation_0-logloss:0.52727
# [20]	validation_0-logloss:0.55525
# [22]	validation_0-logloss:0.37723
# [15]	validation_0-logloss:0.39163
# [31]	validation_0-logloss:0.37006
# [34]	validation_0-logloss:0.36723
# [32]	validation_0-logloss:0.36412
# [22]	validation_0-logloss:0.37670
# [25]	validation_0-logloss:0.53651
# [22]	validation_0-logloss:0.54999
# [14]	validation_0-logloss:0.40721
# [31]	validation_0-logloss:0.37082
# [21]	validation_0-logloss:0.37426
# [28]	validation_0-logloss:0.52408
# [9]	validation_0-logloss:0.43263
# [19]	validation_0-logloss:0.37052
# [23]	validation_0-logloss:0.37722
# [21]	validation_0-logloss:0.36673
# [18]	validation_0-logloss:0.37331
# [2]	validation_0-logloss:0.53850
# [16]	validation_0-logloss:0.39109
# [32]	validation_0-logloss:0.36911
# [15]	validation_0-logloss:0.39873
# [21]	validation_0-logloss:0.55080
# [35]	validation_0-logloss:0.36455
# [33]	validation_0-logloss:0.36411
# [23]	validation_0-logloss:0.37477
# [10]	validation_0-logloss:0.42893
# [27]	validation_0-logloss:0.52359
# [32]	validation_0-logloss:0.36988
# [22]	validation_0-logloss:0.37314
# [24]	validation_0-logloss:0.37367
# [26]	validation_0-logloss:0.53253
# [23]	validation_0-logloss:0.54604
# [20]	validation_0-logloss:0.36792
# [19]	validation_0-logloss:0.37015
# [29]	validation_0-logloss:0.52093
# [3]	validation_0-logloss:0.51478
# [16]	validation_0-logloss:0.39833
# [17]	validation_0-logloss:0.38652
# [33]	validation_0-logloss:0.36838
# [36]	validation_0-logloss:0.36599
# [34]	validation_0-logloss:0.36322
# [24]	validation_0-logloss:0.37166
# [11]	validation_0-logloss:0.41507
# [22]	validation_0-logloss:0.36485
# [33]	validation_0-logloss:0.36937
# [23]	validation_0-logloss:0.37140
# [4]	validation_0-logloss:0.49913
# [22]	validation_0-logloss:0.54632
# [21]	validation_0-logloss:0.36838
# [17]	validation_0-logloss:0.39204
# [18]	validation_0-logloss:0.38223
# [28]	validation_0-logloss:0.51994
# [37]	validation_0-logloss:0.36779
# [25]	validation_0-logloss:0.37155
# [30]	validation_0-logloss:0.51778[12]	validation_0-logloss:0.41125
#
# [35]	validation_0-logloss:0.36496
# [20]	validation_0-logloss:0.36821[27]	validation_0-logloss:0.52857
#
# [34]	validation_0-logloss:0.36893
# [23]	validation_0-logloss:0.36455
# [5]	validation_0-logloss:0.47194[24]	validation_0-logloss:0.37102
#
# [34]	validation_0-logloss:0.37008
# [18]	validation_0-logloss:0.38672[24]	validation_0-logloss:0.54140
# [22]	validation_0-logloss:0.36746
# [38]	validation_0-logloss:0.36884
# [13]	validation_0-logloss:0.40902
# [23]	validation_0-logloss:0.54203
# [25]	validation_0-logloss:0.36964
# [26]	validation_0-logloss:0.37098
# [21]	validation_0-logloss:0.36587
# [24]	validation_0-logloss:0.36169
# [35]	validation_0-logloss:0.36681
#
# [25]	validation_0-logloss:0.36902
# [29]	validation_0-logloss:0.51637
# [36]	validation_0-logloss:0.36551[19]	validation_0-logloss:0.38144
#
# [28]	validation_0-logloss:0.52460[23]	validation_0-logloss:0.36705
#
# [35]	validation_0-logloss:0.36831
# [39]	validation_0-logloss:0.37004
# [14]	validation_0-logloss:0.40746
# [6]	validation_0-logloss:0.46263
# [25]	validation_0-logloss:0.53703
# [27]	validation_0-logloss:0.37217
# [26]	validation_0-logloss:0.36791
# [31]	validation_0-logloss:0.51450[36]	validation_0-logloss:0.36769
# [24]	validation_0-logloss:0.53799
#
# [19]	validation_0-logloss:0.38257
# [22]	validation_0-logloss:0.36410[25]	validation_0-logloss:0.36055
#
# [26]	validation_0-logloss:0.36788
# [20]	validation_0-logloss:0.37992
# [24]	validation_0-logloss:0.36609
# [15]	validation_0-logloss:0.39811
# [40]	validation_0-logloss:0.36815
# [36]	validation_0-logloss:0.36921[37]	validation_0-logloss:0.36426
# [7]	validation_0-logloss:0.45555
#
# [30]	validation_0-logloss:0.51317[29]	validation_0-logloss:0.52120
#
# [28]	validation_0-logloss:0.37063[37]	validation_0-logloss:0.36854
#
# [27]	validation_0-logloss:0.36696
# [23]	validation_0-logloss:0.36247
# [26]	validation_0-logloss:0.53305
# [27]	validation_0-logloss:0.36820
# [26]	validation_0-logloss:0.35984
# [32]	validation_0-logloss:0.51067
# [25]	validation_0-logloss:0.53374
# [16]	validation_0-logloss:0.39823[20]	validation_0-logloss:0.38000
#
# [25]	validation_0-logloss:0.36389
# [8]	validation_0-logloss:0.45051
# [41]	validation_0-logloss:0.37052
# [29]	validation_0-logloss:0.36927
# [38]	validation_0-logloss:0.36277[21]	validation_0-logloss:0.37960
#
# [38]	validation_0-logloss:0.36949
# [37]	validation_0-logloss:0.36886
# [24]	validation_0-logloss:0.36101
# [28]	validation_0-logloss:0.36231
# [28]	validation_0-logloss:0.36490
# [31]	validation_0-logloss:0.50981[17]	validation_0-logloss:0.39190
#
# [26]	validation_0-logloss:0.36127[42]	validation_0-logloss:0.37206
# [21]	validation_0-logloss:0.37854
#
# [30]	validation_0-logloss:0.51822[9]	validation_0-logloss:0.43052
#
# [33]	validation_0-logloss:0.50752[27]	validation_0-logloss:0.52954
#
# [26]	validation_0-logloss:0.52947
# [27]	validation_0-logloss:0.36056
# [39]	validation_0-logloss:0.36230
# [39]	validation_0-logloss:0.37002
# [30]	validation_0-logloss:0.37022
# [25]	validation_0-logloss:0.36007
# [22]	validation_0-logloss:0.37815
# [38]	validation_0-logloss:0.37034
# [29]	validation_0-logloss:0.36448
# [29]	validation_0-logloss:0.35990
# [18]	validation_0-logloss:0.38674
# [27]	validation_0-logloss:0.35766
# [43]	validation_0-logloss:0.37178
# [22]	validation_0-logloss:0.37689
# [10]	validation_0-logloss:0.42599
# [40]	validation_0-logloss:0.36093
# [28]	validation_0-logloss:0.35954
# [39]	validation_0-logloss:0.37049
# [40]	validation_0-logloss:0.36969
# [26]	validation_0-logloss:0.35971
# [31]	validation_0-logloss:0.51471
# [27]	validation_0-logloss:0.52542
# [34]	validation_0-logloss:0.50467
# [30]	validation_0-logloss:0.36181
# [30]	validation_0-logloss:0.36418
# [19]	validation_0-logloss:0.38396
# [23]	validation_0-logloss:0.37589
# [28]	validation_0-logloss:0.52607
# [44]	validation_0-logloss:0.37402
# [32]	validation_0-logloss:0.50591
# [28]	validation_0-logloss:0.35822
# [23]	validation_0-logloss:0.37717
# [41]	validation_0-logloss:0.35871
# [31]	validation_0-logloss:0.36762
# [29]	validation_0-logloss:0.35759
# [11]	validation_0-logloss:0.41305
# [40]	validation_0-logloss:0.37067
# [27]	validation_0-logloss:0.35938
# [41]	validation_0-logloss:0.37227
# [20]	validation_0-logloss:0.38266
# [31]	validation_0-logloss:0.36097
# [31]	validation_0-logloss:0.36139
# [24]	validation_0-logloss:0.37493
# [32]	validation_0-logloss:0.51099
# [28]	validation_0-logloss:0.52151
# [29]	validation_0-logloss:0.35754
# [42]	validation_0-logloss:0.35799
# [32]	validation_0-logloss:0.36792
# [41]	validation_0-logloss:0.37260
# [28]	validation_0-logloss:0.35949
# [12]	validation_0-logloss:0.40872
# [35]	validation_0-logloss:0.50115
# [29]	validation_0-logloss:0.52277
# [21]	validation_0-logloss:0.38152
# [30]	validation_0-logloss:0.35912
# [25]	validation_0-logloss:0.37382
# [42]	validation_0-logloss:0.37316
# [32]	validation_0-logloss:0.36039[32]	validation_0-logloss:0.35985
#
# [24]	validation_0-logloss:0.37447
# [33]	validation_0-logloss:0.50292
# [43]	validation_0-logloss:0.35824
# [29]	validation_0-logloss:0.35864
# [30]	validation_0-logloss:0.35564
# [13]	validation_0-logloss:0.40645
# [42]	validation_0-logloss:0.37237
# [33]	validation_0-logloss:0.50804
# [29]	validation_0-logloss:0.51780
# [33]	validation_0-logloss:0.36834
# [22]	validation_0-logloss:0.38000
# [26]	validation_0-logloss:0.37350
# [33]	validation_0-logloss:0.36120
# [43]	validation_0-logloss:0.37348
# [33]	validation_0-logloss:0.35853
# [36]	validation_0-logloss:0.49780
# [44]	validation_0-logloss:0.36036
# [30]	validation_0-logloss:0.35793
# [25]	validation_0-logloss:0.37175
# [14]	validation_0-logloss:0.40406
# [43]	validation_0-logloss:0.37192
# [23]	validation_0-logloss:0.37816
# [30]	validation_0-logloss:0.51972
# [34]	validation_0-logloss:0.50001
# [31]	validation_0-logloss:0.35820
# [27]	validation_0-logloss:0.37189
# [31]	validation_0-logloss:0.35759
# [34]	validation_0-logloss:0.36660
# [34]	validation_0-logloss:0.36004[34]	validation_0-logloss:0.36145
#
# [44]	validation_0-logloss:0.37457
# [45]	validation_0-logloss:0.35918
# [30]	validation_0-logloss:0.51376
# [31]	validation_0-logloss:0.35588
# [26]	validation_0-logloss:0.37098
# [15]	validation_0-logloss:0.39523
# [24]	validation_0-logloss:0.37768
# [44]	validation_0-logloss:0.37288
# [37]	validation_0-logloss:0.49540
# [34]	validation_0-logloss:0.50478
# [28]	validation_0-logloss:0.37164
# [32]	validation_0-logloss:0.35992
# [32]	validation_0-logloss:0.35708
# [35]	validation_0-logloss:0.36592
# [35]	validation_0-logloss:0.35700
# [35]	validation_0-logloss:0.49609
# [31]	validation_0-logloss:0.51643[32]	validation_0-logloss:0.35425
#
# [35]	validation_0-logloss:0.36233
# [16]	validation_0-logloss:0.39411
# [46]	validation_0-logloss:0.36024
# [27]	validation_0-logloss:0.37116
# [25]	validation_0-logloss:0.37617
# [31]	validation_0-logloss:0.51064
# [35]	validation_0-logloss:0.50140
# [29]	validation_0-logloss:0.37120
# [33]	validation_0-logloss:0.35598
# [36]	validation_0-logloss:0.36694
# [33]	validation_0-logloss:0.36142[36]	validation_0-logloss:0.35894
#
# [38]	validation_0-logloss:0.49297[33]	validation_0-logloss:0.35266
#
# [17]	validation_0-logloss:0.38789
# [36]	validation_0-logloss:0.49291[47]	validation_0-logloss:0.36058
#
# [32]	validation_0-logloss:0.51244
# [26]	validation_0-logloss:0.37559
# [28]	validation_0-logloss:0.36868
# [36]	validation_0-logloss:0.36468
# [30]	validation_0-logloss:0.36906
# [32]	validation_0-logloss:0.50723[34]	validation_0-logloss:0.35646
#
# [34]	validation_0-logloss:0.35271
# [34]	validation_0-logloss:0.36006
# [37]	validation_0-logloss:0.35822
# [37]	validation_0-logloss:0.36638
# [18]	validation_0-logloss:0.38267
# [36]	validation_0-logloss:0.49812
# [39]	validation_0-logloss:0.49088
# [48]	validation_0-logloss:0.35936
# [29]	validation_0-logloss:0.36665
# [31]	validation_0-logloss:0.36844
# [27]	validation_0-logloss:0.37404
# [38]	validation_0-logloss:0.35984
# [38]	validation_0-logloss:0.36775
# [35]	validation_0-logloss:0.36130
# [37]	validation_0-logloss:0.48998
# [35]	validation_0-logloss:0.35381
# [35]	validation_0-logloss:0.35174
# [19]	validation_0-logloss:0.38016
# [33]	validation_0-logloss:0.50427
# [0]	validation_0-logloss:0.63526
# [30]	validation_0-logloss:0.36785
# [49]	validation_0-logloss:0.35811[40]	validation_0-logloss:0.48775
#
# [37]	validation_0-logloss:0.36529
# [32]	validation_0-logloss:0.36694
# [37]	validation_0-logloss:0.49550
# [39]	validation_0-logloss:0.36045
# [36]	validation_0-logloss:0.35256
# [20]	validation_0-logloss:0.37838[36]	validation_0-logloss:0.36112
#
# [28]	validation_0-logloss:0.37332
# [33]	validation_0-logloss:0.50960
# [39]	validation_0-logloss:0.36669
# [1]	validation_0-logloss:0.57327
# [38]	validation_0-logloss:0.48770
# [34]	validation_0-logloss:0.50088
# [31]	validation_0-logloss:0.36536
# [50]	validation_0-logloss:0.35685
# [36]	validation_0-logloss:0.35690
# [38]	validation_0-logloss:0.36668
# [37]	validation_0-logloss:0.35131
# [33]	validation_0-logloss:0.36631
# [0]	validation_0-logloss:0.65821
# [37]	validation_0-logloss:0.36053
# [29]	validation_0-logloss:0.37163
# [21]	validation_0-logloss:0.37765
# [41]	validation_0-logloss:0.48563
# [38]	validation_0-logloss:0.49293
# [2]	validation_0-logloss:0.54277
# [40]	validation_0-logloss:0.36057
# [51]	validation_0-logloss:0.35756
# [34]	validation_0-logloss:0.36505
# [37]	validation_0-logloss:0.35636
# [32]	validation_0-logloss:0.36480
# [35]	validation_0-logloss:0.49801
# [40]	validation_0-logloss:0.36765[34]	validation_0-logloss:0.50658
# [0]	validation_0-logloss:0.66159
#
# [30]	validation_0-logloss:0.37117
# [39]	validation_0-logloss:0.48533
# [38]	validation_0-logloss:0.35091
# [3]	validation_0-logloss:0.50720
# [41]	validation_0-logloss:0.36151
# [22]	validation_0-logloss:0.37540
# [35]	validation_0-logloss:0.36411[39]	validation_0-logloss:0.49040
#
# [33]	validation_0-logloss:0.36545
# [1]	validation_0-logloss:0.63640
# [31]	validation_0-logloss:0.37054
# [38]	validation_0-logloss:0.35747[38]	validation_0-logloss:0.36059
#
# [41]	validation_0-logloss:0.36874
# [39]	validation_0-logloss:0.35132
# [52]	validation_0-logloss:0.35728
# [35]	validation_0-logloss:0.50308
# [36]	validation_0-logloss:0.49511
# [4]	validation_0-logloss:0.48753
# [1]	validation_0-logloss:0.63902[40]	validation_0-logloss:0.48206
#
# [42]	validation_0-logloss:0.48365
# [36]	validation_0-logloss:0.36470[0]	validation_0-logloss:0.66128
#
# [34]	validation_0-logloss:0.36403[32]	validation_0-logloss:0.36866
#
# [40]	validation_0-logloss:0.35119
# [42]	validation_0-logloss:0.36998[42]	validation_0-logloss:0.36191
#
# [2]	validation_0-logloss:0.61348[53]	validation_0-logloss:0.35569
#
# [39]	validation_0-logloss:0.36053[40]	validation_0-logloss:0.48740
# [5]	validation_0-logloss:0.47507
#
# [39]	validation_0-logloss:0.35712
# [37]	validation_0-logloss:0.36287[2]	validation_0-logloss:0.61734
#
# [36]	validation_0-logloss:0.49987[37]	validation_0-logloss:0.49229
#
# [33]	validation_0-logloss:0.36837[41]	validation_0-logloss:0.35094
#
# [43]	validation_0-logloss:0.48084
# [35]	validation_0-logloss:0.36336
# [41]	validation_0-logloss:0.48012[23]	validation_0-logloss:0.37355
#
# [43]	validation_0-logloss:0.37075
# [39]	validation_0-logloss:0.36777[54]	validation_0-logloss:0.35614
#
# [6]	validation_0-logloss:0.45290
# [40]	validation_0-logloss:0.35911
# [3]	validation_0-logloss:0.59354
# [1]	validation_0-logloss:0.63520
# [40]	validation_0-logloss:0.35682
# [42]	validation_0-logloss:0.35117
# [3]	validation_0-logloss:0.59777
# [24]	validation_0-logloss:0.37296
# [36]	validation_0-logloss:0.36519
# [38]	validation_0-logloss:0.48979
# [44]	validation_0-logloss:0.37182
# [34]	validation_0-logloss:0.36721[7]	validation_0-logloss:0.43819
#
# [44]	validation_0-logloss:0.47830
# [55]	validation_0-logloss:0.35774
# [37]	validation_0-logloss:0.49724
# [40]	validation_0-logloss:0.36760
# [42]	validation_0-logloss:0.47796
# [43]	validation_0-logloss:0.35188
# [41]	validation_0-logloss:0.35740
# [4]	validation_0-logloss:0.57629
# [37]	validation_0-logloss:0.36561
# [4]	validation_0-logloss:0.58117[35]	validation_0-logloss:0.36635
#
# [8]	validation_0-logloss:0.42809
# [2]	validation_0-logloss:0.61279[45]	validation_0-logloss:0.37139
#
# [43]	validation_0-logloss:0.36021
# [56]	validation_0-logloss:0.35690
# [45]	validation_0-logloss:0.47547[41]	validation_0-logloss:0.36900
#
# [39]	validation_0-logloss:0.48665
# [42]	validation_0-logloss:0.35822
# [44]	validation_0-logloss:0.35189
# [38]	validation_0-logloss:0.49482
# [43]	validation_0-logloss:0.47491
# [38]	validation_0-logloss:0.36310[36]	validation_0-logloss:0.36709
#
# [38]	validation_0-logloss:0.36682[5]	validation_0-logloss:0.55984
#
# [9]	validation_0-logloss:0.41890
# [41]	validation_0-logloss:0.48521
# [44]	validation_0-logloss:0.36072
# [3]	validation_0-logloss:0.59176
# [5]	validation_0-logloss:0.56621
# [57]	validation_0-logloss:0.35810
# [42]	validation_0-logloss:0.37017
# [45]	validation_0-logloss:0.35109
# [43]	validation_0-logloss:0.35897
# [46]	validation_0-logloss:0.47347
# [37]	validation_0-logloss:0.36599
# [39]	validation_0-logloss:0.36289
# [40]	validation_0-logloss:0.48351[10]	validation_0-logloss:0.41128
#
# [39]	validation_0-logloss:0.36718
# [44]	validation_0-logloss:0.47188
# [39]	validation_0-logloss:0.49243[6]	validation_0-logloss:0.54715
#
# [46]	validation_0-logloss:0.35068
# [0]	validation_0-logloss:0.66155[25]	validation_0-logloss:0.37158
#
# [58]	validation_0-logloss:0.35871
# [42]	validation_0-logloss:0.48308
# [6]	validation_0-logloss:0.55288
# [40]	validation_0-logloss:0.36314
# [38]	validation_0-logloss:0.36569
# [11]	validation_0-logloss:0.40275
# [44]	validation_0-logloss:0.35873
# [47]	validation_0-logloss:0.47175
# [47]	validation_0-logloss:0.34941
# [40]	validation_0-logloss:0.36801
# [7]	validation_0-logloss:0.53615
# [26]	validation_0-logloss:0.37100
# [45]	validation_0-logloss:0.46907
# [41]	validation_0-logloss:0.48058[1]	validation_0-logloss:0.63637
#
# [4]	validation_0-logloss:0.57565[39]	validation_0-logloss:0.36594
#
# [40]	validation_0-logloss:0.48933
# [12]	validation_0-logloss:0.39773
# [7]	validation_0-logloss:0.54322
# [59]	validation_0-logloss:0.35713[45]	validation_0-logloss:0.35817
# [48]	validation_0-logloss:0.34998
#
# [41]	validation_0-logloss:0.37017
# [27]	validation_0-logloss:0.37004
# [8]	validation_0-logloss:0.52400
# [40]	validation_0-logloss:0.36621
# [5]	validation_0-logloss:0.55963
# [48]	validation_0-logloss:0.46994[60]	validation_0-logloss:0.35833
#
# [13]	validation_0-logloss:0.39260
# [43]	validation_0-logloss:0.48035
# [46]	validation_0-logloss:0.46683
# [8]	validation_0-logloss:0.53172
# [2]	validation_0-logloss:0.61411
# [49]	validation_0-logloss:0.35027
# [41]	validation_0-logloss:0.48730
# [28]	validation_0-logloss:0.36924
# [42]	validation_0-logloss:0.37117
# [42]	validation_0-logloss:0.47768[41]	validation_0-logloss:0.36642
#
# [9]	validation_0-logloss:0.50747
# [14]	validation_0-logloss:0.38895
# [50]	validation_0-logloss:0.35057
# [41]	validation_0-logloss:0.36328
# [6]	validation_0-logloss:0.54609[44]	validation_0-logloss:0.47783
#
# [61]	validation_0-logloss:0.35739
# [9]	validation_0-logloss:0.51703
# [47]	validation_0-logloss:0.46457
# [43]	validation_0-logloss:0.37148
# [42]	validation_0-logloss:0.36657
# [42]	validation_0-logloss:0.48535
# [0]	validation_0-logloss:0.66785
# [3]	validation_0-logloss:0.59514
# [15]	validation_0-logloss:0.38455
# [51]	validation_0-logloss:0.35051
# [42]	validation_0-logloss:0.36358
# [29]	validation_0-logloss:0.36768
# [43]	validation_0-logloss:0.47492
# [49]	validation_0-logloss:0.46834
# [7]	validation_0-logloss:0.53454
# [10]	validation_0-logloss:0.49847
# [43]	validation_0-logloss:0.36740
# [44]	validation_0-logloss:0.37274
# [10]	validation_0-logloss:0.50840
# [43]	validation_0-logloss:0.36387
# [52]	validation_0-logloss:0.35072
# [16]	validation_0-logloss:0.38182
# [45]	validation_0-logloss:0.47512
# [48]	validation_0-logloss:0.46272
# [4]	validation_0-logloss:0.57895
# [1]	validation_0-logloss:0.63942
# [43]	validation_0-logloss:0.48246
# [62]	validation_0-logloss:0.35589
# [44]	validation_0-logloss:0.36714
# [53]	validation_0-logloss:0.35044
# [11]	validation_0-logloss:0.48714
# [45]	validation_0-logloss:0.37196[8]	validation_0-logloss:0.52291
# [17]	validation_0-logloss:0.37963
#
# [50]	validation_0-logloss:0.46653
# [11]	validation_0-logloss:0.49630
# [30]	validation_0-logloss:0.36595
# [5]	validation_0-logloss:0.56344[0]	validation_0-logloss:0.67700
#
# [2]	validation_0-logloss:0.61752
# [44]	validation_0-logloss:0.47974
# [44]	validation_0-logloss:0.36419
# [49]	validation_0-logloss:0.46073
# [18]	validation_0-logloss:0.37831
# [31]	validation_0-logloss:0.36596
# [1]	validation_0-logloss:0.66261
# [12]	validation_0-logloss:0.47923
# [54]	validation_0-logloss:0.35011
# [46]	validation_0-logloss:0.47291
# [44]	validation_0-logloss:0.47260
# [2]	validation_0-logloss:0.64798
# [45]	validation_0-logloss:0.36643
# [9]	validation_0-logloss:0.50989
# [32]	validation_0-logloss:0.36382[12]	validation_0-logloss:0.48851
#
# [6]	validation_0-logloss:0.54981
# [45]	validation_0-logloss:0.47710[3]	validation_0-logloss:0.59610
#
# [3]	validation_0-logloss:0.63480
# [55]	validation_0-logloss:0.34990
# [50]	validation_0-logloss:0.45912
# [19]	validation_0-logloss:0.37668
# [51]	validation_0-logloss:0.46390
# [13]	validation_0-logloss:0.47380
# [46]	validation_0-logloss:0.36640
# [45]	validation_0-logloss:0.36370
# [4]	validation_0-logloss:0.62282
# [33]	validation_0-logloss:0.36319
# [47]	validation_0-logloss:0.47106
# [45]	validation_0-logloss:0.47039
# [56]	validation_0-logloss:0.34919
# [13]	validation_0-logloss:0.48236
# [20]	validation_0-logloss:0.37332
# [10]	validation_0-logloss:0.50313
# [51]	validation_0-logloss:0.45659
# [7]	validation_0-logloss:0.53935
# [46]	validation_0-logloss:0.36347
# [4]	validation_0-logloss:0.58093
# [46]	validation_0-logloss:0.47489
# [14]	validation_0-logloss:0.46883
# [57]	validation_0-logloss:0.34824
# [47]	validation_0-logloss:0.36686
# [48]	validation_0-logloss:0.46938
# [21]	validation_0-logloss:0.37262
# [46]	validation_0-logloss:0.46822
# [52]	validation_0-logloss:0.46242
# [11]	validation_0-logloss:0.49244
# [14]	validation_0-logloss:0.47740
# [5]	validation_0-logloss:0.61111
# [8]	validation_0-logloss:0.52868
# [58]	validation_0-logloss:0.34868
# [52]	validation_0-logloss:0.45481
# [47]	validation_0-logloss:0.47291
# [22]	validation_0-logloss:0.37075
# [34]	validation_0-logloss:0.36206
# [15]	validation_0-logloss:0.45960
# [5]	validation_0-logloss:0.56690
# [59]	validation_0-logloss:0.34868
# [53]	validation_0-logloss:0.45972
# [47]	validation_0-logloss:0.46556
# [23]	validation_0-logloss:0.36915
# [15]	validation_0-logloss:0.46963
# [12]	validation_0-logloss:0.48587
# [6]	validation_0-logloss:0.60081
# [35]	validation_0-logloss:0.36166
# [53]	validation_0-logloss:0.45226
# [9]	validation_0-logloss:0.51382
# [16]	validation_0-logloss:0.45493
# [60]	validation_0-logloss:0.34870
# [7]	validation_0-logloss:0.59160
# [49]	validation_0-logloss:0.46770
# [48]	validation_0-logloss:0.47111
# [24]	validation_0-logloss:0.36767
# [6]	validation_0-logloss:0.54761
# [8]	validation_0-logloss:0.58326
# [36]	validation_0-logloss:0.36149
# [54]	validation_0-logloss:0.45838
# [48]	validation_0-logloss:0.46302
# [61]	validation_0-logloss:0.34802
# [9]	validation_0-logloss:0.57314
# [10]	validation_0-logloss:0.50721
# [54]	validation_0-logloss:0.45064
# [17]	validation_0-logloss:0.44725
# [13]	validation_0-logloss:0.47832
# [25]	validation_0-logloss:0.36422
# [37]	validation_0-logloss:0.35983
# [10]	validation_0-logloss:0.56563
# [49]	validation_0-logloss:0.46929
# [7]	validation_0-logloss:0.53295
# [62]	validation_0-logloss:0.34776
# [49]	validation_0-logloss:0.46106
# [50]	validation_0-logloss:0.46576
# [16]	validation_0-logloss:0.46489
# [11]	validation_0-logloss:0.55675
# [55]	validation_0-logloss:0.45703
# [26]	validation_0-logloss:0.36268
# [11]	validation_0-logloss:0.49586
# [38]	validation_0-logloss:0.36043
# [14]	validation_0-logloss:0.47361
# [0]	validation_0-logloss:0.67722
# [63]	validation_0-logloss:0.34763
# [55]	validation_0-logloss:0.44900
# [12]	validation_0-logloss:0.54960
# [50]	validation_0-logloss:0.46770
# [18]	validation_0-logloss:0.43999
# [51]	validation_0-logloss:0.46327
# [27]	validation_0-logloss:0.36063
# [1]	validation_0-logloss:0.66399
# [17]	validation_0-logloss:0.45588
# [50]	validation_0-logloss:0.45879
# [13]	validation_0-logloss:0.54357
# [56]	validation_0-logloss:0.45484
# [64]	validation_0-logloss:0.34722
# [12]	validation_0-logloss:0.48926
# [15]	validation_0-logloss:0.46560
# [2]	validation_0-logloss:0.64954
# [8]	validation_0-logloss:0.51948
# [14]	validation_0-logloss:0.53834
# [39]	validation_0-logloss:0.35980
# [28]	validation_0-logloss:0.35994
# [51]	validation_0-logloss:0.46525
# [56]	validation_0-logloss:0.44660
# [19]	validation_0-logloss:0.43219
# [3]	validation_0-logloss:0.63677
# [18]	validation_0-logloss:0.44806
# [13]	validation_0-logloss:0.48272
# [65]	validation_0-logloss:0.34757
# [57]	validation_0-logloss:0.45340
# [4]	validation_0-logloss:0.62509
# [29]	validation_0-logloss:0.35878
# [52]	validation_0-logloss:0.46150
# [40]	validation_0-logloss:0.36026
# [9]	validation_0-logloss:0.50913
# [52]	validation_0-logloss:0.46368
# [5]	validation_0-logloss:0.61420
# [51]	validation_0-logloss:0.45667
# [66]	validation_0-logloss:0.34795
# [57]	validation_0-logloss:0.44505
# [20]	validation_0-logloss:0.42560
# [41]	validation_0-logloss:0.35994
# [6]	validation_0-logloss:0.60394
# [30]	validation_0-logloss:0.35784
# [14]	validation_0-logloss:0.47872
# [0]	validation_0-logloss:0.67662
# [15]	validation_0-logloss:0.53082
# [58]	validation_0-logloss:0.45190
# [10]	validation_0-logloss:0.50134
# [67]	validation_0-logloss:0.34822
# [16]	validation_0-logloss:0.46152
# [7]	validation_0-logloss:0.59511
# [1]	validation_0-logloss:0.66234
# [53]	validation_0-logloss:0.46128
# [52]	validation_0-logloss:0.45444
# [42]	validation_0-logloss:0.36028
# [58]	validation_0-logloss:0.44377
# [21]	validation_0-logloss:0.42284
# [2]	validation_0-logloss:0.64861
# [8]	validation_0-logloss:0.58715
# [31]	validation_0-logloss:0.35780
# [68]	validation_0-logloss:0.34848
# [53]	validation_0-logloss:0.45903
# [11]	validation_0-logloss:0.49083
# [3]	validation_0-logloss:0.63670
# [43]	validation_0-logloss:0.36009
# [16]	validation_0-logloss:0.52620
# [0]	validation_0-logloss:0.67616
# [53]	validation_0-logloss:0.45238
# [19]	validation_0-logloss:0.44064[59]	validation_0-logloss:0.45041
#
# [69]	validation_0-logloss:0.34825
# [4]	validation_0-logloss:0.62531
# [54]	validation_0-logloss:0.45966
# [17]	validation_0-logloss:0.45188[22]	validation_0-logloss:0.41842
#
# [15]	validation_0-logloss:0.47001
# [44]	validation_0-logloss:0.35984[59]	validation_0-logloss:0.44236
#
# [17]	validation_0-logloss:0.51949
# [5]	validation_0-logloss:0.61367
# [32]	validation_0-logloss:0.35757
# [1]	validation_0-logloss:0.66228
# [54]	validation_0-logloss:0.45740
# [12]	validation_0-logloss:0.48276
# [18]	validation_0-logloss:0.51347[70]	validation_0-logloss:0.34812
#
# [2]	validation_0-logloss:0.64830[20]	validation_0-logloss:0.43457
# [23]	validation_0-logloss:0.41402
#
# [60]	validation_0-logloss:0.44915
# [16]	validation_0-logloss:0.46697
# [33]	validation_0-logloss:0.35693
# [54]	validation_0-logloss:0.45024
# [6]	validation_0-logloss:0.60428
# [55]	validation_0-logloss:0.45825
# [3]	validation_0-logloss:0.63592
# [19]	validation_0-logloss:0.50801
# [71]	validation_0-logloss:0.34858
# [45]	validation_0-logloss:0.35950
# [60]	validation_0-logloss:0.44098
# [13]	validation_0-logloss:0.47589[4]	validation_0-logloss:0.62427
#
# [24]	validation_0-logloss:0.40960
# [20]	validation_0-logloss:0.50301
# [18]	validation_0-logloss:0.44420
# [21]	validation_0-logloss:0.43141
# [55]	validation_0-logloss:0.45603
# [9]	validation_0-logloss:0.57770
# [5]	validation_0-logloss:0.61325
# [17]	validation_0-logloss:0.45713
# [55]	validation_0-logloss:0.44845
# [21]	validation_0-logloss:0.49903
# [72]	validation_0-logloss:0.34861
# [61]	validation_0-logloss:0.44791
# [34]	validation_0-logloss:0.35591
# [46]	validation_0-logloss:0.35939
# [10]	validation_0-logloss:0.57046
# [22]	validation_0-logloss:0.49447
# [7]	validation_0-logloss:0.59597
# [73]	validation_0-logloss:0.34851
# [56]	validation_0-logloss:0.45604
# [6]	validation_0-logloss:0.60360
# [35]	validation_0-logloss:0.35540
# [11]	validation_0-logloss:0.56197
# [56]	validation_0-logloss:0.45387
# [8]	validation_0-logloss:0.58859
# [22]	validation_0-logloss:0.42717
# [19]	validation_0-logloss:0.43861
# [56]	validation_0-logloss:0.44667
# [18]	validation_0-logloss:0.45002
# [61]	validation_0-logloss:0.43966
# [62]	validation_0-logloss:0.44589
# [9]	validation_0-logloss:0.57835
# [47]	validation_0-logloss:0.35970
# [25]	validation_0-logloss:0.40781[14]	validation_0-logloss:0.46752
# [7]	validation_0-logloss:0.59469
# [10]	validation_0-logloss:0.57158
# [36]	validation_0-logloss:0.35545
# [12]	validation_0-logloss:0.55505
# [23]	validation_0-logloss:0.42406
# [57]	validation_0-logloss:0.45459
# [57]	validation_0-logloss:0.44505
# [11]	validation_0-logloss:0.56256
# [8]	validation_0-logloss:0.58682
# [63]	validation_0-logloss:0.44473
# [37]	validation_0-logloss:0.35478
# [19]	validation_0-logloss:0.44340
# [15]	validation_0-logloss:0.45828
# [62]	validation_0-logloss:0.43749
# [12]	validation_0-logloss:0.55606
# [9]	validation_0-logloss:0.57714
# [20]	validation_0-logloss:0.43318
# [48]	validation_0-logloss:0.35884
# [13]	validation_0-logloss:0.54909
# [57]	validation_0-logloss:0.45246
# [13]	validation_0-logloss:0.55044
# [10]	validation_0-logloss:0.57002
# [58]	validation_0-logloss:0.45317
# [14]	validation_0-logloss:0.54392
# [23]	validation_0-logloss:0.49043
# [24]	validation_0-logloss:0.41923
# [58]	validation_0-logloss:0.44362
# ...
# [59]	validation_0-logloss:0.31281
# [100]	validation_0-logloss:0.38058
# [120]	validation_0-logloss:0.36546
# [108]	validation_0-logloss:0.36906
# [104]	validation_0-logloss:0.38122
# [53]	validation_0-logloss:0.32621
# [58]	validation_0-logloss:0.32636
# [118]	validation_0-logloss:0.37748
# [121]	validation_0-logloss:0.36547
# [109]	validation_0-logloss:0.36872[50]	validation_0-logloss:0.30837
#
# [50]	validation_0-logloss:0.31747
# [101]	validation_0-logloss:0.38042
# [60]	validation_0-logloss:0.31213
# [105]	validation_0-logloss:0.38069
# [54]	validation_0-logloss:0.32575
# [119]	validation_0-logloss:0.37729
# [122]	validation_0-logloss:0.36516
# [59]	validation_0-logloss:0.32479
# [110]	validation_0-logloss:0.36866[106]	validation_0-logloss:0.38022
#
# [102]	validation_0-logloss:0.37987
# [61]	validation_0-logloss:0.30877
# [51]	validation_0-logloss:0.31674
# [51]	validation_0-logloss:0.30759
# [120]	validation_0-logloss:0.37698
# [107]	validation_0-logloss:0.37975
# [123]	validation_0-logloss:0.36508
# [55]	validation_0-logloss:0.32493
# [60]	validation_0-logloss:0.32406
# [111]	validation_0-logloss:0.36772
# [103]	validation_0-logloss:0.37994
# [108]	validation_0-logloss:0.37922
# [121]	validation_0-logloss:0.37734
# [62]	validation_0-logloss:0.30930
# [52]	validation_0-logloss:0.31742
# [124]	validation_0-logloss:0.36468
# [104]	validation_0-logloss:0.37968
# [112]	validation_0-logloss:0.36752
# [52]	validation_0-logloss:0.30963
# [61]	validation_0-logloss:0.32148
# [109]	validation_0-logloss:0.37934
# [122]	validation_0-logloss:0.37703[56]	validation_0-logloss:0.32750
#
# [113]	validation_0-logloss:0.36716
# [125]	validation_0-logloss:0.36426[105]	validation_0-logloss:0.37884
#
# [63]	validation_0-logloss:0.30932
# [110]	validation_0-logloss:0.37895
# [123]	validation_0-logloss:0.37714
# [114]	validation_0-logloss:0.36682
# [57]	validation_0-logloss:0.32939
# [62]	validation_0-logloss:0.32260
# [126]	validation_0-logloss:0.36435
# [106]	validation_0-logloss:0.37862
# [64]	validation_0-logloss:0.30729
# [115]	validation_0-logloss:0.36653
# [124]	validation_0-logloss:0.37663
# [111]	validation_0-logloss:0.37879
# [127]	validation_0-logloss:0.36358
# [58]	validation_0-logloss:0.32891
# [107]	validation_0-logloss:0.37817
# [65]	validation_0-logloss:0.30765
# [116]	validation_0-logloss:0.36657
# [63]	validation_0-logloss:0.32186
# [128]	validation_0-logloss:0.36346
# [125]	validation_0-logloss:0.37638
# [112]	validation_0-logloss:0.37903
# [59]	validation_0-logloss:0.32705
# [117]	validation_0-logloss:0.36689
# [129]	validation_0-logloss:0.36355
# [108]	validation_0-logloss:0.37766
# [66]	validation_0-logloss:0.30785
# [118]	validation_0-logloss:0.36648
# [130]	validation_0-logloss:0.36330
# [113]	validation_0-logloss:0.37905
# [64]	validation_0-logloss:0.31793
# [126]	validation_0-logloss:0.37663
# [60]	validation_0-logloss:0.32504
# [109]	validation_0-logloss:0.37769
# [119]	validation_0-logloss:0.36659
# [131]	validation_0-logloss:0.36281[67]	validation_0-logloss:0.30752
#
# [114]	validation_0-logloss:0.37892
# [61]	validation_0-logloss:0.32414
# [127]	validation_0-logloss:0.37607
# [110]	validation_0-logloss:0.37735
# [65]	validation_0-logloss:0.31876
# [120]	validation_0-logloss:0.36630
# [132]	validation_0-logloss:0.36269
# [62]	validation_0-logloss:0.32507
# [115]	validation_0-logloss:0.37895
# [68]	validation_0-logloss:0.30874
# [128]	validation_0-logloss:0.37586
# [111]	validation_0-logloss:0.37691
# [133]	validation_0-logloss:0.36247
# [121]	validation_0-logloss:0.36619
# [66]	validation_0-logloss:0.31665
# [63]	validation_0-logloss:0.32363
# [116]	validation_0-logloss:0.37920
# [129]	validation_0-logloss:0.37568
# [69]	validation_0-logloss:0.30952
# [112]	validation_0-logloss:0.37723
# [134]	validation_0-logloss:0.36228[122]	validation_0-logloss:0.36546
#
# [64]	validation_0-logloss:0.31971
# [67]	validation_0-logloss:0.31870
# [117]	validation_0-logloss:0.37917
# [130]	validation_0-logloss:0.37524
# [113]	validation_0-logloss:0.37742
# [123]	validation_0-logloss:0.36536
# [135]	validation_0-logloss:0.36187
# [70]	validation_0-logloss:0.31037
# [65]	validation_0-logloss:0.31981
# [131]	validation_0-logloss:0.37476
# [118]	validation_0-logloss:0.37903
# [68]	validation_0-logloss:0.31869
# [114]	validation_0-logloss:0.37688
# [124]	validation_0-logloss:0.36544
# [136]	validation_0-logloss:0.36143
# [66]	validation_0-logloss:0.31900
# [71]	validation_0-logloss:0.31143
# [132]	validation_0-logloss:0.37500
# [119]	validation_0-logloss:0.37880
# [115]	validation_0-logloss:0.37692
# [137]	validation_0-logloss:0.36131
# [125]	validation_0-logloss:0.36524
# [69]	validation_0-logloss:0.32048
# [67]	validation_0-logloss:0.31950
# [133]	validation_0-logloss:0.37467
# [120]	validation_0-logloss:0.37858
# [72]	validation_0-logloss:0.30935
# [138]	validation_0-logloss:0.36115
# [116]	validation_0-logloss:0.37718
# [126]	validation_0-logloss:0.36473
# [68]	validation_0-logloss:0.32109
# [134]	validation_0-logloss:0.37465
# [70]	validation_0-logloss:0.32354
# [121]	validation_0-logloss:0.37885
# [139]	validation_0-logloss:0.36094
# [117]	validation_0-logloss:0.37705
# [127]	validation_0-logloss:0.36465
# [69]	validation_0-logloss:0.32122
# [73]	validation_0-logloss:0.31185
# [135]	validation_0-logloss:0.37456
# [122]	validation_0-logloss:0.37846
# [140]	validation_0-logloss:0.36069
# [71]	validation_0-logloss:0.32535
# [118]	validation_0-logloss:0.37693
# [128]	validation_0-logloss:0.36466
# [70]	validation_0-logloss:0.32463
# [136]	validation_0-logloss:0.37430
# [141]	validation_0-logloss:0.36055
# [123]	validation_0-logloss:0.37863
# [119]	validation_0-logloss:0.37654
# [129]	validation_0-logloss:0.36454
# [72]	validation_0-logloss:0.32606
# [142]	validation_0-logloss:0.36072
# [71]	validation_0-logloss:0.32469
# [124]	validation_0-logloss:0.37818
# [137]	validation_0-logloss:0.37367
# [143]	validation_0-logloss:0.36068
# [120]	validation_0-logloss:0.37631
# [130]	validation_0-logloss:0.36430
# [144]	validation_0-logloss:0.36034
# [73]	validation_0-logloss:0.32687
# [138]	validation_0-logloss:0.37355
# [125]	validation_0-logloss:0.37816
# [121]	validation_0-logloss:0.37668
# [72]	validation_0-logloss:0.32576
# [131]	validation_0-logloss:0.36467
# [145]	validation_0-logloss:0.36027
# [139]	validation_0-logloss:0.37361
# [146]	validation_0-logloss:0.35999
# [126]	validation_0-logloss:0.37816
# [74]	validation_0-logloss:0.32608
# [132]	validation_0-logloss:0.36487
# [122]	validation_0-logloss:0.37629
# [147]	validation_0-logloss:0.35952
# [73]	validation_0-logloss:0.32645
# [140]	validation_0-logloss:0.37311
# [127]	validation_0-logloss:0.37785
# [123]	validation_0-logloss:0.37602
# [148]	validation_0-logloss:0.35918
# [133]	validation_0-logloss:0.36490
# [75]	validation_0-logloss:0.32770
# [149]	validation_0-logloss:0.35922
# [141]	validation_0-logloss:0.37288
# [128]	validation_0-logloss:0.37760
# [74]	validation_0-logloss:0.32686
# [124]	validation_0-logloss:0.37571
# [134]	validation_0-logloss:0.36507
# [150]	validation_0-logloss:0.35956
# [76]	validation_0-logloss:0.32604
# [142]	validation_0-logloss:0.37277
# [129]	validation_0-logloss:0.37733
# [151]	validation_0-logloss:0.35966
# [125]	validation_0-logloss:0.37551
# [135]	validation_0-logloss:0.36497
# [75]	validation_0-logloss:0.32628
# [143]	validation_0-logloss:0.37268
# [152]	validation_0-logloss:0.35983
# [130]	validation_0-logloss:0.37673
# [136]	validation_0-logloss:0.36446
# [126]	validation_0-logloss:0.37537
# [153]	validation_0-logloss:0.35908
# [76]	validation_0-logloss:0.32598
# [144]	validation_0-logloss:0.37220
# [131]	validation_0-logloss:0.37654
# [154]	validation_0-logloss:0.35879
# [137]	validation_0-logloss:0.36420
# [127]	validation_0-logloss:0.37517
# [145]	validation_0-logloss:0.37174
# [155]	validation_0-logloss:0.35843
# [132]	validation_0-logloss:0.37682
# [128]	validation_0-logloss:0.37498
# [138]	validation_0-logloss:0.36407
# [156]	validation_0-logloss:0.35831
# [146]	validation_0-logloss:0.37110
# [129]	validation_0-logloss:0.37443
# [133]	validation_0-logloss:0.37669
# [157]	validation_0-logloss:0.35818
# [139]	validation_0-logloss:0.36428
# [130]	validation_0-logloss:0.37387
# [147]	validation_0-logloss:0.37057
# [158]	validation_0-logloss:0.35828
# [134]	validation_0-logloss:0.37647
# [131]	validation_0-logloss:0.37357
# [140]	validation_0-logloss:0.36451
# [159]	validation_0-logloss:0.35815
# [132]	validation_0-logloss:0.37389
# [148]	validation_0-logloss:0.37071
# [141]	validation_0-logloss:0.36468
# [160]	validation_0-logloss:0.35825
# [135]	validation_0-logloss:0.37630
# [133]	validation_0-logloss:0.37361
# [161]	validation_0-logloss:0.35843
# [142]	validation_0-logloss:0.36447
# [149]	validation_0-logloss:0.37091
# [136]	validation_0-logloss:0.37606
# [162]	validation_0-logloss:0.35852
# [134]	validation_0-logloss:0.37351
# [143]	validation_0-logloss:0.36444
# [163]	validation_0-logloss:0.35813[135]	validation_0-logloss:0.37348
#
# [144]	validation_0-logloss:0.36456[150]	validation_0-logloss:0.37107
#
# [137]	validation_0-logloss:0.37538
# [136]	validation_0-logloss:0.37317
# [164]	validation_0-logloss:0.35808
# [145]	validation_0-logloss:0.36445
# [151]	validation_0-logloss:0.37113
# [137]	validation_0-logloss:0.37246[138]	validation_0-logloss:0.37538
#
# [165]	validation_0-logloss:0.35777
# [146]	validation_0-logloss:0.36406
# [138]	validation_0-logloss:0.37248
# [166]	validation_0-logloss:0.35761
# [152]	validation_0-logloss:0.37121[139]	validation_0-logloss:0.37558
#
# [147]	validation_0-logloss:0.36383
# [139]	validation_0-logloss:0.37277
# [167]	validation_0-logloss:0.35794
# [148]	validation_0-logloss:0.36362
# [140]	validation_0-logloss:0.37513
# [153]	validation_0-logloss:0.37087
# [168]	validation_0-logloss:0.35760
# [140]	validation_0-logloss:0.37263
# [149]	validation_0-logloss:0.36363
# [169]	validation_0-logloss:0.35805
# [141]	validation_0-logloss:0.37210
# [141]	validation_0-logloss:0.37476
# [154]	validation_0-logloss:0.37079
# [150]	validation_0-logloss:0.36357
# [170]	validation_0-logloss:0.35815
# [142]	validation_0-logloss:0.37221
# [151]	validation_0-logloss:0.36330[142]	validation_0-logloss:0.37477
#
# [171]	validation_0-logloss:0.35823
# [155]	validation_0-logloss:0.37056
# [143]	validation_0-logloss:0.37151
# [152]	validation_0-logloss:0.36346
# [172]	validation_0-logloss:0.35791
# [144]	validation_0-logloss:0.37151
# [156]	validation_0-logloss:0.37033
# [143]	validation_0-logloss:0.37444
# [173]	validation_0-logloss:0.35816
# [153]	validation_0-logloss:0.36352
# [145]	validation_0-logloss:0.37108
# [157]	validation_0-logloss:0.36990
# [174]	validation_0-logloss:0.35827
# [154]	validation_0-logloss:0.36303
# [144]	validation_0-logloss:0.37432
# [146]	validation_0-logloss:0.37052
# [155]	validation_0-logloss:0.36270
# [175]	validation_0-logloss:0.35843
# [147]	validation_0-logloss:0.36992
# [145]	validation_0-logloss:0.37358
# [158]	validation_0-logloss:0.36996
# [176]	validation_0-logloss:0.35792
# [156]	validation_0-logloss:0.36232
# [148]	validation_0-logloss:0.37012
# [146]	validation_0-logloss:0.37305
# [177]	validation_0-logloss:0.35793
# [159]	validation_0-logloss:0.36988
# [157]	validation_0-logloss:0.36211
# [149]	validation_0-logloss:0.37034
# [158]	validation_0-logloss:0.36181
# [178]	validation_0-logloss:0.35824
# [147]	validation_0-logloss:0.37237
# [150]	validation_0-logloss:0.37017
# [160]	validation_0-logloss:0.36972
# [159]	validation_0-logloss:0.36182
# [151]	validation_0-logloss:0.37003
# [160]	validation_0-logloss:0.36128
# [148]	validation_0-logloss:0.37252
# [161]	validation_0-logloss:0.36982
# [152]	validation_0-logloss:0.37015
# [161]	validation_0-logloss:0.36119
# [153]	validation_0-logloss:0.36928
# [149]	validation_0-logloss:0.37246
# [162]	validation_0-logloss:0.36995
# [154]	validation_0-logloss:0.36952
# [162]	validation_0-logloss:0.36150
# [150]	validation_0-logloss:0.37240
# [155]	validation_0-logloss:0.36941
# [163]	validation_0-logloss:0.36186
# [163]	validation_0-logloss:0.36995
# [164]	validation_0-logloss:0.36141
# [156]	validation_0-logloss:0.36940
# [151]	validation_0-logloss:0.37234
# [164]	validation_0-logloss:0.36997
# [157]	validation_0-logloss:0.36941
# [165]	validation_0-logloss:0.36159
# [152]	validation_0-logloss:0.37228
# [166]	validation_0-logloss:0.36144
# [158]	validation_0-logloss:0.36945
# [165]	validation_0-logloss:0.36983
# [159]	validation_0-logloss:0.36941
# [167]	validation_0-logloss:0.36147
# [153]	validation_0-logloss:0.37136
# [166]	validation_0-logloss:0.36980
# [168]	validation_0-logloss:0.36126
# [160]	validation_0-logloss:0.36907
# [154]	validation_0-logloss:0.37140
# [169]	validation_0-logloss:0.36144
# [161]	validation_0-logloss:0.36885
# [167]	validation_0-logloss:0.37010
# [170]	validation_0-logloss:0.36154
# [155]	validation_0-logloss:0.37107
# [162]	validation_0-logloss:0.36838
# [171]	validation_0-logloss:0.36181
# [168]	validation_0-logloss:0.36973
# [163]	validation_0-logloss:0.36826
# [156]	validation_0-logloss:0.37088
# [164]	validation_0-logloss:0.36815
# [169]	validation_0-logloss:0.37024
# [157]	validation_0-logloss:0.37057
# [165]	validation_0-logloss:0.36809
# [166]	validation_0-logloss:0.36805
# [170]	validation_0-logloss:0.37043[158]	validation_0-logloss:0.37065
#
# [167]	validation_0-logloss:0.36829
# [159]	validation_0-logloss:0.37066
# [168]	validation_0-logloss:0.36793
# [169]	validation_0-logloss:0.36825
# [160]	validation_0-logloss:0.37075
# [170]	validation_0-logloss:0.36878
# [161]	validation_0-logloss:0.37086
# [171]	validation_0-logloss:0.36928
# [172]	validation_0-logloss:0.36930
# [162]	validation_0-logloss:0.37058
# [173]	validation_0-logloss:0.36923
# [163]	validation_0-logloss:0.37065
# [174]	validation_0-logloss:0.36956
# [164]	validation_0-logloss:0.37067
# [175]	validation_0-logloss:0.36995
# [165]	validation_0-logloss:0.37068
# [176]	validation_0-logloss:0.36974
# [166]	validation_0-logloss:0.37030
# [177]	validation_0-logloss:0.36996
# [167]	validation_0-logloss:0.37047
# [178]	validation_0-logloss:0.37017
# [168]	validation_0-logloss:0.37019
# [169]	validation_0-logloss:0.37064
# [170]	validation_0-logloss:0.37114
# [171]	validation_0-logloss:0.37153
# [172]	validation_0-logloss:0.37147
# [173]	validation_0-logloss:0.37128
# [174]	validation_0-logloss:0.37170
# [175]	validation_0-logloss:0.37208
# [176]	validation_0-logloss:0.37214
# [177]	validation_0-logloss:0.37210
# [0]	validation_0-logloss:0.62772
# [1]	validation_0-logloss:0.59246
# [2]	validation_0-logloss:0.56799
# [3]	validation_0-logloss:0.55114
# [4]	validation_0-logloss:0.54499
# [5]	validation_0-logloss:0.47551
# [6]	validation_0-logloss:0.44104
# [7]	validation_0-logloss:0.42069
# [8]	validation_0-logloss:0.41746
# [9]	validation_0-logloss:0.40252
# [10]	validation_0-logloss:0.40153
# [11]	validation_0-logloss:0.39283
# [12]	validation_0-logloss:0.38659
# [13]	validation_0-logloss:0.37910
# [14]	validation_0-logloss:0.37773
# [15]	validation_0-logloss:0.37490
# [16]	validation_0-logloss:0.37205
# [17]	validation_0-logloss:0.36985
# [18]	validation_0-logloss:0.36655
# [19]	validation_0-logloss:0.36432
# [20]	validation_0-logloss:0.36512
# [21]	validation_0-logloss:0.36532
# [22]	validation_0-logloss:0.36747
# [23]	validation_0-logloss:0.36564
# [24]	validation_0-logloss:0.36665
# [25]	validation_0-logloss:0.36429
# [26]	validation_0-logloss:0.36733
# [27]	validation_0-logloss:0.36580
# [28]	validation_0-logloss:0.36739
# [29]	validation_0-logloss:0.36374
# [30]	validation_0-logloss:0.36109
# [31]	validation_0-logloss:0.36126
# [32]	validation_0-logloss:0.36202
# [33]	validation_0-logloss:0.36010
# [34]	validation_0-logloss:0.36184
# [35]	validation_0-logloss:0.36209
# [36]	validation_0-logloss:0.35917
# [37]	validation_0-logloss:0.36052
# [38]	validation_0-logloss:0.35971
# [39]	validation_0-logloss:0.35741
# [40]	validation_0-logloss:0.35921
# [41]	validation_0-logloss:0.35800
# [42]	validation_0-logloss:0.35985
# [43]	validation_0-logloss:0.36100
# [44]	validation_0-logloss:0.35857
# [45]	validation_0-logloss:0.35974
# [46]	validation_0-logloss:0.35669
# [47]	validation_0-logloss:0.35584
# [48]	validation_0-logloss:0.35535
# [49]	validation_0-logloss:0.35807
# [50]	validation_0-logloss:0.35930
# [51]	validation_0-logloss:0.36311
# [52]	validation_0-logloss:0.36278
# [53]	validation_0-logloss:0.35826
# [54]	validation_0-logloss:0.35805
# [55]	validation_0-logloss:0.36028
# [56]	validation_0-logloss:0.36157
# [57]	validation_0-logloss:0.36316
# [58]	validation_0-logloss:0.36203
# Best parameters: {'colsample_bytree': np.float64(0.761287213218212), 'gamma': np.float64(0.6064496054554777), 'learning_rate': np.float64(0.2682893147260598), 'max_depth': 5, 'min_child_weight': 7, 'n_estimators': 400, 'subsample': np.float64(0.7826079565050621)}
# Best score: 0.8715808708399386

# %% [markdown]
# ## 4.2 HARUS

# %%
harus_xgb = XGBClassifier(
    objective='multi:softmax',
    tree_method='exact',
    n_jobs=-1,
    early_stopping_rounds=10
)

harus_random_search = RandomizedSearchCV(
    estimator=harus_xgb, 
    param_distributions=searchspace, 
    scoring='accuracy',
    n_iter=250, 
    cv=5,
    n_jobs=-1, 
    verbose=1, 
    random_state=0
)
harus_random_search.fit(harus_xtrain, harus_ytrain,
                  eval_set = harus_ev_val,
                  verbose=False)

# Print best parameters
print(f"Best parameters: {harus_random_search.best_params_}")
print(f"Best score: {harus_random_search.best_score_}")
# Out:
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits

# %% [markdown]
# ## 4.3 SeMu

# %%
semu_xgb = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    n_jobs=-1,
    early_stopping_rounds=10,
)

semu_random_search = RandomizedSearchCV(
    estimator=semu_xgb, 
    param_distributions=searchspace, 
    scoring='accuracy',
    n_iter=250, 
    cv=5,
    n_jobs=-1, 
    verbose=1, 
    random_state=0
)
semu_random_search.fit(
    semu_xtrain, semu_ytrain,
    eval_set=semu_ev_val,
    verbose=True
)

# Print best parameters
print(f"Best parameters: {semu_random_search.best_params_}")
print(f"Best score: {semu_random_search.best_score_}")

# %% [markdown]
# # 5 Modelle mit optimierten Hyperparametern erzeugen

# %% [markdown]
# ## 5.1 AGMP

# %%
pre_agmp = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    n_jobs=-1,
    early_stopping_rounds=10,
    scale_pos_weight=classratio,
    n_estimators=agmp_random_search.best_params_['n_estimators'],
    max_depth=agmp_random_search.best_params_['max_depth'],
    min_child_weight=agmp_random_search.best_params_['min_child_weight'],
    subsample=agmp_random_search.best_params_['subsample'],
    colsample_bytree=agmp_random_search.best_params_['colsample_bytree'],
    learning_rate=agmp_random_search.best_params_['learning_rate'],
    gamma=agmp_random_search.best_params_['gamma'],
)

pre_agmp.fit(
    agmp_xtrain, 
    agmp_ytrain,
    eval_set=agmp_ev_val,
    verbose=False
)

agmp_best_iteration = pre_agmp.best_iteration
print(f'n_estimators nach best_iteration: {agmp_best_iteration}')

agmp = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    scale_pos_weight=classratio,
    n_jobs=-1,
    n_estimators=agmp_best_iteration,
    max_depth=agmp_random_search.best_params_['max_depth'],
    min_child_weight=agmp_random_search.best_params_['min_child_weight'],
    subsample=agmp_random_search.best_params_['subsample'],
    colsample_bytree=agmp_random_search.best_params_['colsample_bytree'],
    learning_rate=agmp_random_search.best_params_['learning_rate'],
    gamma=agmp_random_search.best_params_['gamma'],
)

agmp.fit(
    agmp_xtrain, agmp_ytrain
)
# Out:
# n_estimators nach best_iteration: 99
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8712237640848051, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.2157529115709422,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05873233119671418,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=99, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## 5.2 HARUS

# %%
pre_harus = XGBClassifier(
    objective = "multi:softmax",
    tree_method = 'exact',
    early_stopping_rounds = 10,
    n_jobs = -1,
    n_estimators = harus_random_search.best_params_['n_estimators'],
    max_depth = harus_random_search.best_params_['max_depth'],
    min_child_weight = harus_random_search.best_params_['min_child_weight'],
    subsample = harus_random_search.best_params_['subsample'],
    colsample_bytree = harus_random_search.best_params_['colsample_bytree'],
    learning_rate = harus_random_search.best_params_['learning_rate'],
    gamma = harus_random_search.best_params_['gamma'],
)

pre_harus.fit(
    harus_xtrain, 
    harus_ytrain,
    eval_set=harus_ev_val,
    verbose=False
)

harus_best_iteration = pre_harus.best_iteration
print(f'n_estimators nach best_iteration: {harus_best_iteration}')

harus = XGBClassifier(
    objective = "multi:softmax",
    tree_method = 'exact',
    n_jobs = -1,
    n_estimators = harus_best_iteration,
    max_depth = harus_random_search.best_params_['max_depth'],
    min_child_weight = harus_random_search.best_params_['min_child_weight'],
    subsample = harus_random_search.best_params_['subsample'],
    colsample_bytree = harus_random_search.best_params_['colsample_bytree'],
    learning_rate = harus_random_search.best_params_['learning_rate'],
    gamma = harus_random_search.best_params_['gamma'],
)

harus.fit(
    harus_xtrain, harus_ytrain
)
# Out:
# n_estimators nach best_iteration: 255
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8582280977824015, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.12828994860439275,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.13481670745733776,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=255, n_jobs=-1,
#               num_parallel_tree=None, objective='multi:softmax', ...)

# %% [markdown]
# ## 5.3 SeMu

# %%
pre_semu = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    n_jobs=-1,
    early_stopping_rounds=10,
    n_estimators = semu_random_search.best_params_['n_estimators'],
    max_depth = semu_random_search.best_params_['max_depth'],
    min_child_weight = semu_random_search.best_params_['min_child_weight'],
    subsample = semu_random_search.best_params_['subsample'],
    colsample_bytree = semu_random_search.best_params_['colsample_bytree'],
    learning_rate = semu_random_search.best_params_['learning_rate'],
    gamma = semu_random_search.best_params_['gamma'],
)

pre_semu.fit(
    semu_xtrain, 
    semu_ytrain,
    eval_set=semu_ev_val,
    verbose=False
)

semu_best_iteration = pre_semu.best_iteration
print(f'n_estimators nach best_iteration: {semu_best_iteration}')

semu = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    n_jobs=-1,
    n_estimators = semu_best_iteration,
    max_depth = semu_random_search.best_params_['max_depth'],
    min_child_weight = semu_random_search.best_params_['min_child_weight'],
    subsample = semu_random_search.best_params_['subsample'],
    colsample_bytree = semu_random_search.best_params_['colsample_bytree'],
    learning_rate = semu_random_search.best_params_['learning_rate'],
    gamma = semu_random_search.best_params_['gamma'],
)
semu.fit(
    semu_xtrain, semu_ytrain
)
# Out:
# n_estimators nach best_iteration: 121
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.919231607902399, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0.540795176148389,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2943352730637827,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=121, n_jobs=-1,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# # 6 Ermittelte Hyperparameter sichern

# %%
hyperparam_quicksave = "Gefundene Hyperparameter:\n"
hyperparam_quicksave += f"##### Agmp #####\n {agmp_random_search.best_params_}\n"
hyperparam_quicksave += f"nach best_iteration: {agmp_best_iteration}\n"
hyperparam_quicksave += f"##### Harus #####\n {harus_random_search.best_params_}\n"
hyperparam_quicksave += f"nach best_iteration: {harus_best_iteration}\n"
hyperparam_quicksave += f"##### Semu #####\n {semu_random_search.best_params_}\n"
hyperparam_quicksave += f"nach best_iteration: {semu_best_iteration}\n"
with open("hyperparameter_quicksave.txt", "w") as file:
    file.write(hyperparam_quicksave)

# %% [markdown]
# # 7 Modelle mit optimierten Parametern erzeugen

# %%
agmp_opt = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    scale_pos_weight=classratio,
    n_jobs=-1,
    max_depth=5,
    n_estimators=48,
    learning_rate=0.2682893147260598,
    min_child_weight=7,
    subsample=0.7826079565050621,
    colsample_bytree=0.761287213218212,
    gamma=0.6064496054554777,
)

harus_opt = XGBClassifier(
    objective='multi:softmax',
    tree_method='exact',
    n_jobs=-1,
    max_depth=3,
    n_estimators=249,
    learning_rate=0.13481670745733776,
    min_child_weight=1,
    subsample=0.6575317462724224,
    colsample_bytree=0.8582280977824015,
    gamma=0.12828994860439275,
)

semu_opt = XGBClassifier(
    objective='binary:logistic',
    tree_method='exact',
    n_jobs=-1,
    max_depth=5,
    n_estimators=499,
    learning_rate=0.15027487381296678,
    min_child_weight=3,
    subsample=0.7599248560037323,
    colsample_bytree=0.63998340623714,
    gamma=0.13172036479303575,
)

agmp_opt.fit(
    agmp_xtrain, agmp_ytrain
)
harus_opt.fit(
    harus_xtrain, harus_ytrain
)
semu_opt.fit(
    semu_xtrain, semu_ytrain
)

agmp_opt.save_model("model-exports/aktuelle-exports/combined/agmp_comb.json")
harus_opt.save_model("model-exports/aktuelle-exports/combined/harus_comb.json")
semu_opt.save_model("model-exports/aktuelle-exports/combined/semu_comb.json")

# %% [markdown]
# # 8 Scores quantisieren

# %%
import json

def getScaleZP(modeldata, amountBits):
    min = 0.0
    max = 0.0
    
    for tree in modeldata['learner']['gradient_booster']['model']['trees']:
        nodescount = int(tree['tree_param']['num_nodes'])
        
        for i in range(nodescount):
            if int(tree['left_children'][i]) == -1:
                if float(tree['split_conditions'][i]) < min:
                    min = float(tree['split_conditions'][i])
                if float(tree['split_conditions'][i]) > max:
                    max = float(tree['split_conditions'][i])

    print(f"min: {min}, max: {max}")

    print(f'Amount of Bits: {amountBits} -> Skala: {(2**amountBits)-1} ')
    scale = ((2**amountBits)-1) / (max - min)
    zp = (-(round(scale*min))) - 128

    return scale, zp


def quantizeScores(modeldata, scale, zp):
    for tree in modeldata['learner']['gradient_booster']['model']['trees']:
        nodescount = int(tree['tree_param']['num_nodes'])
        
        for i in range(nodescount):
            if int(tree['left_children'][i]) == -1:
                score = float(tree['split_conditions'][i])
                tree['split_conditions'][i] = float(round(scale * score + zp))
                
    return modeldata

# %%
with open('model-exports/aktuelle-exports/combined/agmp_comb.json') as f:
    agmp_json = json.load(f)

with open('model-exports/aktuelle-exports/combined/harus_comb.json') as f:
    harus_json = json.load(f)

with open('model-exports/aktuelle-exports/combined/semu_comb.json') as f:
    semu_json = json.load(f)

agmp_scale, agmp_zp = getScaleZP(agmp_json, 8)
harus_scale, harus_zp = getScaleZP(harus_json, 8)
semu_scale, semu_zp = getScaleZP(semu_json, 8)

agmp_json = quantizeScores(agmp_json, agmp_scale, agmp_zp)
harus_json = quantizeScores(harus_json, harus_scale, harus_zp)
semu_json = quantizeScores(semu_json, semu_scale, semu_zp)
# Out:
# min: -0.2923554, max: 0.55096006
# Amount of Bits: 8 -> Skala: 255
# min: -0.1465948, max: 0.4027076
# Amount of Bits: 8 -> Skala: 255
# min: -0.445063, max: 0.40438992
# Amount of Bits: 8 -> Skala: 255

# %%
with open('model-exports/aktuelle-exports/combined/agmp_comb.json', 'w') as f:
    json.dump(agmp_json, f, separators=(',', ':'))
with open('model-exports/aktuelle-exports/combined/harus_comb.json', 'w') as f:
    json.dump(harus_json, f, separators=(',', ':'))
with open('model-exports/aktuelle-exports/combined/semu_comb.json', 'w') as f:
    json.dump(semu_json, f, separators=(',', ':'))

# %% [markdown]
# # 9 Portieren

# %%
def portToC(model, filename):
    path = 'model-exports/plainC/'

    with open(path + filename,'w') as f:
        code = m2c.export_to_c(model)
        f.write(code)

    print(f'Model exported to: "{path + filename}"')

agmp_opt.load_model("model-exports/aktuelle-exports/combined/agmp_comb.json")
agmp_opt.set_params(base_score = float(agmp_opt.base_score))
print(float(agmp_opt.base_score))
portToC(agmp_opt, 'agmp_combined.c')

harus_opt.load_model("model-exports/aktuelle-exports/combined/harus_comb.json")
harus_opt.set_params(base_score = float(harus_opt.base_score),
                     num_parallel_tree = 1)
print(float(harus_opt.base_score))
portToC(harus_opt, 'harus_combined.c')

semu_opt.load_model("model-exports/aktuelle-exports/combined/semu_comb.json")
semu_opt.set_params(base_score = float(semu_opt.base_score))
print(float(semu_opt.base_score))
portToC(semu_opt, 'semu_combined.c')
# Out:
# 0.49990478
# Model exported to: "model-exports/plainC/agmp_combined.c"
# 0.5
# Model exported to: "model-exports/plainC/harus_combined.c"
# 0.55469894
# Model exported to: "model-exports/plainC/semu_combined.c"
